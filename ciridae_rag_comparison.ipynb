# %%
# !pip install -q PyMuPDF unstructured

# %%
# !pip install PyPDF2

# %%
pdf_1_file = open(pdf_1_path, 'rb')
pdf_2_file = open(pdf_2_path, 'rb')

# %%
import fitz
from IPython.display import display, Markdown

def preview_pdf_structure(path, pages=[0, 1, 2]):
    doc = fitz.open(path)
    for i in pages:
        page = doc[i]
        text = page.get_text("text")
        display(Markdown(f"### 📄 Page {i+1}\n\n```{text}```"))

# Replace with your path
preview_pdf_structure(pdf_1_path, pages=[0, 1, 2, 3, 4])
# Out:
# ### 📄 Page 1
#
# ```
#
# Configurazione Wi-Fi Aruba:
# access point e terminali
#
# IO_XX_00_XX
#
#
#
#
# Pagina  di
#
# 1
# 51
#
#
# ISTRUZIONE OPERATIVA
# 14/10/2024
# CONFIGURAZIONE WI-FI ARUBA:
# ACCESS POINT E TERMINALI
# MATRICE DELLE REVISIONI
# REVISION
# E
# DATA
# DESCRIZION
# E
# REDAZION
# E
# VERIFICATA
# APPROVATA
# 00
# 14.10.202
# 4
# 1a emissione
# Gruppo di
# lavoro
# RSGI/RQ/RSPPGA/
# RSTRUTT
# DG/DS/DA/
# DSS
# 01
# 31.10.202
# 4
# Modifica
# Par.4,
# Par.5.1.1,
# Par.5.1.4
# Gruppo di
# lavoro
# RSGI/RQ/RSPPGA/
# RSTRUTT
# DG/DS/DA/
# DSS
# ```
# ### 📄 Page 2
#
# ```
#
# Configurazione Wi-Fi Aruba:
# access point e terminali
#
# IO_XX_00_XX
#
#
#
#
# Pagina  di
#
# 2
# 51
#
#
# ISTRUZIONE OPERATIVA
# 14/10/2024
# GRUPPO DI LAVORO PER LA REDAZIONE
# Cognome e nome
# Qualifica
# Struttura di appartenenza
# Predonzan Tomaso
# Network administrator
# ASUGI
# Monti Maurizio
# Network administrator
# ASUGI
# Chiffi Francesco
# System Senior Expert
# BV-Tech
# ```
# ### 📄 Page 3
#
# ```
#
# Configurazione Wi-Fi Aruba:
# access point e terminali
#
# IO_XX_00_XX
#
#
#
#
# Pagina  di
#
# 3
# 51
#
#
# ISTRUZIONE OPERATIVA
# 14/10/2024
# INDICE
# 1. SCOPO
#
# ..........................................................................................................................4
# 2. AMBITO DI APPLICAZIONE
#
# ..........................................................................................4
# 3. ACRONIMI E DEFINIZIONI
#
# ...........................................................................................4
# 4. RESPONSABILITA’
#
# ........................................................................................................4
# 5. MODALITÀ ESECUTIVE
#
# ...............................................................................................5
# 5.1.
# CONFIGURAZIONE DELL’INFRASTRUTTURA
#
# ..................................................................5
# 5.1.1. ARCHITETTURA DELL’INFRASTRUTTURA WI-FI
#
# ........................................................................5
# 5.1.2. ACCESSO AL MOBILITY CONDUCTOR
#
# ........................................................................................7
# 5.1.3. CONFIGURAZIONE ACCESS POINT
#
# ...........................................................................................11
# 5.1.3.1. WLAN
#
# ......................................................................................................................................................11
# 5.1.3.1.1. DETTAGLIO WLAN - GENERAL
#
# ............................................................................................................................12
# 5.1.3.1.2. DETTAGLIO WLAN – VLANS
#
# .................................................................................................................................13
# 5.1.3.1.3. DETTAGLIO WLAN – SECURITY
#
# ..........................................................................................................................14
# 5.1.3.1.4. DETTAGLIO WLAN – ACCESS
#
# ..............................................................................................................................15
# 5.1.3.2. ROLES & POLICIES
#
# ...............................................................................................................................16
# 5.1.3.2.1. DETTAGLIO ROLES & POLICIES - ROLES
#
# ..........................................................................................................17
# 5.1.3.2.2. DETTAGLIO ROLES & POLICIES - POLICIES
#
# ......................................................................................................17
# 5.1.3.2.3. DETTAGLIO ROLES & POLICIES - APPLICATIONS
#
# .............................................................................................18
# 5.1.3.2.4. DETTAGLIO ROLES & POLICIES - ALIASES
#
# ........................................................................................................18
# 5.1.3.3. ACCESS POINTS
#
# ...................................................................................................................................19
# 5.1.3.3.1. DETTAGLIO ACCES POINTS – CAMPUS APS
#
# .....................................................................................................19
# 5.1.3.4. AP GROUPS
#
# ...........................................................................................................................................22
# 5.1.3.4.1. DETTAGLIO AP GROUPS - APS
#
# ............................................................................................................................22
# 5.1.3.5. AUTHENTICATION
#
# .................................................................................................................................23
# 5.1.3.5.1. DETTAGLIO AUTH SERVERS
#
# ...............................................................................................................................24
# 5.1.3.6. SERVICES
#
# ..............................................................................................................................................27
# 5.1.3.7. INTERFACES
#
# ..........................................................................................................................................28
# 5.1.3.8. CONTROLLERS
#
# .....................................................................................................................................29
# 5.1.3.9. SYSTEM
#
# ..................................................................................................................................................29
# 5.1.3.10.TASKS
#
# .....................................................................................................................................................30
# 5.1.3.11.REDUNDANCY
#
# .......................................................................................................................................31
# 5.1.3.12.IOT
#
# 32
# 5.1.4. AGGIUNTA DI UN NUOVO ACCESS POINT
#
# ................................................................................33
# 5.2.
# CONFIGURAZIONE DEI TERMINALI
#
# ................................................................................34
# 5.2.1. PROCEDURA CONFIGURAZIONE TERMINALE
#
# .........................................................................34
# 5.2.2. VERIFICA CONNESSIONE TERMINALE
#
# .....................................................................................46
# 5.2.2.1. CLIENT
#
# ....................................................................................................................................................46
# 5.2.2.2. WLAN
#
# ......................................................................................................................................................48
# 6. GESTIONE DELLA DOCUMENTAZIONE
#
# ...................................................................49
# 7. RIFERIMENTI (NORMATIVI E BIBLIOGRAFICI)
#
# ........................................................49
# 7.1.
# ARUBAOS
#
# ..........................................................................................................................49
# 7.2.
# WI-FI CONTROLLER
#
# .........................................................................................................49
# 7.3.
# ACCESS POINT
#
# .................................................................................................................49
# 8. DOCUMENTI COLLEGATI
#
# ..........................................................................................49
# 9. ALLEGATI (SE PRESENTI)
#
# .........................................................................................49
# 10.INDICE DELLE FIGURE	..............................................................................................50
# ```
# ### 📄 Page 4
#
# ```
#
# Configurazione Wi-Fi Aruba:
# access point e terminali
#
# IO_XX_00_XX
#
#
#
#
# Pagina  di
#
# 4
# 51
#
#
# ISTRUZIONE OPERATIVA
# 14/10/2024
# 1. SCOPO
# Scopo del presente documento è la definizione delle istruzioni operative relative a:
# •
# Configurazione access point.
# •
# Configurazione terminali.
# 2. AMBITO DI APPLICAZIONE
# L’ambito di applicazione del presente documento è inerente alla configurazione dei ‘Wireless
# Controller’, degli ‘Access point’ e dei terminali che devono usufruire della rete wireless gestita dagli
# apparati precedentemente citati.
# NOTA BENE:
# •
# Tutti i parametri e le configurazioni per le quali non venga esplicitamente indicata una
# azione di modifica nel presente documento, devono essere lasciati inalterati ai valori di
# default già presenti. La modifica di tali valori potrebbe causare anomalie di funzionamento.
# 3. ACRONIMI E DEFINIZIONI
# •
# 802.1X: standard IEEE che fornisce un meccanismo di autenticazione dei dispositivi che
# vogliono collegarsi tramite uno switch o un access point Wi-Fi ad una rete LAN o WLAN .
# 1
# •
# Aruba Mobility Conductor: dispositivo centralizzato per la gestione dei wireless Controller
# e relativi access point.
# 2
# •
# Aruba Wireless Controller: dispositivo centralizzato per la gestione degli access point .
# 3
# •
# Aruba Access Point: dispositivo periferico per la gestione della connettività Wi-Fi .
# 4
# 4. RESPONSABILITA’
# •
# ASUGI:
# o
# Tomaso Predonzan
# o
# Maurizio Monti
# o
# Borut Jarc
# •
# BVTECH:
# o
# Mauro Apolloni
# o
# Francesco Chiffi
# •
# INSIEL:
# o
# Christian Zorzi
#  https://it.wikipedia.org/wiki/IEEE_802.1x
# 1
#  https://www.arubanetworks.com/it/prodotti/wireless/Controller/mobility-Conductor/
# 2
#  https://www.arubanetworks.com/it/prodotti/wireless/Controller/
# 3
#  https://www.hpe.com/it/it/aruba-access-points.html
# 4
# ```
# ### 📄 Page 5
#
# ```
#
# Configurazione Wi-Fi Aruba:
# access point e terminali
#
# IO_XX_00_XX
#
#
#
#
# Pagina  di
#
# 5
# 51
#
#
# ISTRUZIONE OPERATIVA
# 14/10/2024
# 5. MODALITÀ ESECUTIVE
# 5.1.
# CONFIGURAZIONE DELL’INFRASTRUTTURA
# 5.1.1. ARCHITETTURA DELL’INFRASTRUTTURA WI-FI
# L’infrastruttura si può suddividere in tre componenti principali:
# •
# La componente core costituita dall’ ‘Aruba Mobility Conductor’ che è in carico ad INSIEL.
# •
# La componente perimetrale, costituita dagli ‘Aruba Wireless Controller’ (ARCN9240)
# disposti presso le varie sedi di ASUGI, nello specifico al momento in cui viene redatto il
# presente documento ne sono presenti complessivamente 8:
# o
# Ospedale Cattinara (Trieste): 2 Wireless Controller dotati di doppio modulo di
# alimentazione connessi su sistemi di alimentazione differenziata.
# o
# Ospedale Monfalcone: 2 Wireless Controller dotati di doppio modulo di
# alimentazione.
# o
# Ospedale Gorizia: 2 Wireless Controller dotati di doppio modulo di alimentazione.
# o
# Ospedale Maggiore (Trieste): 2 Wireless Controller dotati di doppio modulo di
# alimentazione connessi su sistemi di alimentazione differenziata.
# sono disposti in coppia per assicurare ridondanza in caso di malfunzionamento di uno di
# essi (alta affidabilità). Come si evince, essi sono disposti su base geografica. Utilizzano,
# ognuno una aggregazione di due fibre a 10 GBPS per il collegamento verso il ‘Mobility
# Conductor’, per la gestione degli ‘Access point’ e per la gestione del traffico effettivo di rete.
# •
# La componente di accesso, costituita dagli Access Point, (ARUBA AP515) disposti nelle
# varie sedi secondo le conformazioni degli ambienti e le necessità locali.
# In breve, il ‘Mobility Conductor’ consente la gestione centralizzata di tutti i ‘Wireless Controller’, che
# a loro volta si occupano di gestire gli ‘Access point’ secondo criteri che saranno dettagliati in
# seguito.
# Di seguito un diagramma logico dell’infrastruttura:
# ```

# %% [markdown]
# IF caption_y < 150 AND
#    no image is matched AND
#    previous page has unmatched embedded image:
#    → assign that image

# %%
import fitz
import os
import re
import json
from PIL import Image
import io

def dynamic_crop_above_caption(doc, pdf_name, page_num, caption_text, caption_rect, output_folder, fig_num, dpi=300):
    page = doc[page_num]
    x0, y0, x1, y1 = caption_rect
    caption_y = y0

    print(f"\n🔍 [Figura {fig_num}] Using provided caption rect on page {page_num + 1}: {caption_rect}")

    pix = page.get_pixmap(dpi=dpi)
    img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
    scale = dpi / 72

    # 2. Collect vector figure borders
    drawing_rects = []
    print("🔍 Scanning vector borders on page...")
    for i, draw in enumerate(page.get_drawings()):
        r = draw["rect"]
        lw = draw.get("linewidth", 1.0)
        stroke = draw.get("color", (0, 0, 0))
        fill = draw.get("fill")

        print(f"   ➤ Rect {i}: {r}, lw={lw}, fill={fill}, stroke={stroke}")

        if lw <= 1.0 and fill is None and stroke in [(0, 0, 0), (0.3, 0.3, 0.3)]:
            print(f"     ✅ Passed visual filter")
            if abs(r.y1 - caption_y) < 100:
                print(f"     ✅ Passed caption proximity: y1={r.y1:.2f}, caption_y={caption_y:.2f}")
                drawing_rects.append(r)
            else:
                print(f"     ❌ Failed caption proximity: y1={r.y1:.2f}, caption_y={caption_y:.2f}")
        else:
            print(f"     ❌ Failed visual filter")

    if drawing_rects:
        closest_rect = min(drawing_rects, key=lambda r: abs(r.y1 - caption_y))
        crop_px = (
            int(closest_rect.x0 * scale),
            int(closest_rect.y0 * scale),
            int(closest_rect.x1 * scale),
            int(closest_rect.y1 * scale)
        )
        cropped = img.crop(crop_px)

        filename = f"{pdf_name}_figure_{fig_num}.png"
        out_path = os.path.join(output_folder, filename)
        cropped.save(out_path)
        print(f"📐 Cropped from vector box: figure {fig_num} on page {page_num + 1}")

        return {
            "filename": filename,
            "figure_id": f"Figura {fig_num}",
            "caption": caption_text,
            "page": page_num + 1,
            "rendered": True,
            "source": "vector_box_crop"
        }

    else:
        print("⚠️ No vector border found — trying embedded image fallback...")
        images = page.get_images(full=True)
        valid_images = images[1:] if len(images) > 1 else []

        if valid_images:
            xref = valid_images[0][0]  # assume first non-header image
            image_data = doc.extract_image(xref)
            image_bytes = image_data["image"]

            filename = f"{pdf_name}_figure_{fig_num}.png"
            out_path = os.path.join(output_folder, filename)
            Image.open(io.BytesIO(image_bytes)).save(out_path)
            print(f"🖼️ Saved embedded fallback image for figure {fig_num} on page {page_num + 1}")

            return {
                "filename": filename,
                "figure_id": f"Figura {fig_num}",
                "caption": caption_text,
                "page": page_num + 1,
                "rendered": False,
                "source": "embedded_image_fallback"
            }

        else:
            print("❌ No embedded image found either, skipping figure.")
            return None

def extract_all_figures_with_captions(pdf_path, pdf_name, output_folder) -> dict:
    os.makedirs(output_folder, exist_ok=True)
    doc = fitz.open(pdf_path)

    figure_pattern = re.compile(r"Figura\s+(\d+)\s*[-–—]\s*(.*)", re.IGNORECASE)
    figure_map = {}

    for page_num in range(len(doc)):
        page = doc[page_num]
        blocks = page.get_text("blocks")

        for block in blocks:
            text = block[4].strip()
            match = figure_pattern.match(text)

            if match:
                fig_num = match.group(1)
                caption = match.group(2).strip()
                print(f"🔎 Found caption match: Figura {fig_num} — '{caption}' on page {page_num + 1}")

                if fig_num in figure_map:
                    print(f"⚠️ Skipping Figura {fig_num} on page {page_num + 1} — already in map")
                    continue

                caption_rect = block[:4]
                crop_result = dynamic_crop_above_caption(doc, pdf_name, page_num, caption, caption_rect, output_folder, fig_num)
                if crop_result:
                    figure_map[fig_num] = crop_result

    print(f"✅ Extracted {len(figure_map)} figures using vector-based cropping")

    # Save metadata
    metadata_path = os.path.join(output_folder, "figure_metadata.json")
    with open(metadata_path, "w", encoding="utf-8") as f:
        json.dump(figure_map, f, indent=2, ensure_ascii=False)

    print(f"📝 Saved metadata to {metadata_path}")
    return figure_map

# %%
import fitz
import os
import re
import json
from PIL import Image
import io


import re

def sanitize_caption(caption):
    return re.sub(r'[^\w\s-]', '', caption).strip().replace(' ', '_')[:60]

def dynamic_crop_above_caption(doc, pdf_name, page_num, caption_text, caption_rect, output_folder, fig_num, dpi=300):
    def process_page(page, caption_y, image_page_num, proximity_strategy="abs", fallback=False):
        pix = page.get_pixmap(dpi=dpi)
        img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
        scale = dpi / 72
        page_height = page.rect.height

        drawing_rects = []
        print("🔍 Scanning vector borders on page...")
        for i, draw in enumerate(page.get_drawings()):
            r = draw["rect"]
            lw = draw.get("linewidth", 1.0)
            stroke = draw.get("color", (0, 0, 0))
            fill = draw.get("fill")

            print(f"   ➤ Rect {i}: {r}, lw={lw}, fill={fill}, stroke={stroke}")

            if lw <= 1.0 and fill is None and stroke in [(0, 0, 0), (0.3, 0.3, 0.3)]:
                print(f"     ✅ Passed visual filter")
                if proximity_strategy == "abs":
                    if abs(r.y1 - caption_y) < 100:
                        print(f"     ✅ Passed caption proximity: y1={r.y1:.2f}, caption_y={caption_y:.2f}")
                        drawing_rects.append(r)
                    else:
                        print(f"     ❌ Failed caption proximity")
                elif proximity_strategy == "bleed":
                    bottom_margin = 150  # pixels from bottom considered for bleed-over
                    if (page_height - r.y1) < bottom_margin:
                        print(f"     ✅ Passed bleed-over proximity (y1={r.y1:.2f}, page_height={page_height:.2f})")
                        drawing_rects.append(r)
                    else:
                        print(f"     ❌ Failed bleed-over proximity (y1={r.y1:.2f} >= {bottom_margin:.2f})")
            else:
                print(f"     ❌ Failed visual filter")

        if drawing_rects:
            closest_rect = min(drawing_rects, key=lambda r: abs(r.y1 - caption_y))
            crop_px = (
                int(closest_rect.x0 * scale),
                int(closest_rect.y0 * scale),
                int(closest_rect.x1 * scale),
                int(closest_rect.y1 * scale)
            )
            cropped = img.crop(crop_px)

            filename = f"{pdf_name}_figure_{fig_num}.png"  # fig_num here is the full unique_id e.g., "69_VMware_NSX"
            out_path = os.path.join(output_folder, filename)
            cropped.save(out_path)
            print(f"📐 Cropped from vector box: figure {fig_num} from page {image_page_num + 1}")

            return {
                "filename": filename,
                "figure_id": f"Figura {fig_num}",
                "caption": caption_text,
                "page": page_num + 1,
                "image_page": image_page_num + 1,
                "rendered": True,
                "source": "bleed_over_crop" if fallback else "vector_box_crop"
            }
        return None

    page = doc[page_num]
    x0, y0, x1, y1 = caption_rect
    caption_y = y0

    print(f"\n🔍 [Figura {fig_num}] Using provided caption rect on page {page_num + 1}: {caption_rect}")
    result = process_page(page, caption_y, page_num, proximity_strategy="abs")

    if result:
        return result

    # === Determine order of fallback based on caption position ===
    caption_is_top_of_page = caption_y < 200  # Tuneable threshold

    if caption_is_top_of_page and page_num > 0:
        print("↪️ Caption is high on the page — trying previous page first (bleed-over)...")
        prev_page = doc[page_num - 1]
        result = process_page(prev_page, caption_y, page_num - 1, proximity_strategy="bleed", fallback=True)
        if result:
            return result

    # Embedded image fallback — select the one closest *above* the caption
    # 📎 Embedded image fallback — select image just above the caption
    print("📎 Trying embedded image fallback on caption page (using top-aligned matching)...")
    image_infos = page.get_image_info(xrefs=True)

    # Filter only images whose top is above the caption
    image_above_caption = [
        info for info in image_infos
        if info["bbox"][1] < caption_y
    ]

    print(f"🔍 Found {len(image_infos)} embedded images with position info on page {page_num + 1}")
    print(f"🧪 Caption Y: {caption_y}")
    for info in image_above_caption:
        print(f"   ➤ Image bbox: {info['bbox']}")

    if image_above_caption:
        # Choose the image whose top is closest to caption_y (i.e. closest image above the caption)
        closest_image = max(image_above_caption, key=lambda info: info["bbox"][1])
        xref = closest_image["xref"]

        image_data = doc.extract_image(xref)
        image_bytes = image_data["image"]

        filename = f"{pdf_name}_figure_{fig_num}.png"
        out_path = os.path.join(output_folder, filename)
        Image.open(io.BytesIO(image_bytes)).save(out_path)
        print(f"🖼️ Saved embedded image just above caption for figure {fig_num} on page {page_num + 1}")

        return {
            "filename": filename,
            "figure_id": f"Figura {fig_num}",
            "caption": caption_text,
            "page": page_num + 1,
            "image_page": page_num + 1,
            "rendered": False,
            "source": "embedded_image_fallback"
        }








    print("❌ No embedded image found either, skipping figure.")
    return None

def extract_all_figures_with_captions(pdf_path, pdf_name, output_folder) -> dict:
    os.makedirs(output_folder, exist_ok=True)
    doc = fitz.open(pdf_path)

    figure_pattern = re.compile(r"Figura\s+(\d+)\s*[-–—]\s*(.*)", re.IGNORECASE)
    figure_map = {}
    seen_figures = set()

    for page_num in range(len(doc)):
        page = doc[page_num]
        blocks = page.get_text("blocks")

        for block in blocks:
            text = block[4].strip()
            match = figure_pattern.match(text)

            if match:
                fig_num = match.group(1)
                caption = match.group(2).strip().lower()
                figure_key = (fig_num, caption)

                print(f"🔎 Found caption match: Figura {fig_num} — '{caption}' on page {page_num + 1}")

                safe_caption = sanitize_caption(caption)
                unique_id = f"{fig_num}_{safe_caption}"

                # Avoid duplicate caption-text (very unlikely if caption is full)
                if unique_id in figure_map:
                    print(f"⚠️ Skipping Figura {fig_num} — duplicate caption")
                    continue

                caption_rect = block[:4]

                crop_result = dynamic_crop_above_caption(
                    doc, pdf_name, page_num, caption, caption_rect,
                    output_folder, unique_id  # used for both image name + key
                )

                if crop_result:
                    figure_map[unique_id] = crop_result


    print(f"✅ Extracted {len(figure_map)} figures using vector-based cropping")

    metadata_path = os.path.join(output_folder, "figure_metadata.json")
    with open(metadata_path, "w", encoding="utf-8") as f:
        json.dump(figure_map, f, indent=2, ensure_ascii=False)

    print(f"📝 Saved metadata to {metadata_path}")
    return figure_map

# %%
import os

# === Config ===
pdf_path = '/data/VM_manual/ISTRUZIONE_OPERATIVA_CREAZIONE_VM_CLOUD_INSIEL_REV_00.pdf'
output_folder_path = '/data/VM_manual'
pdf_name = 'VM_manual'

# Create subfolder for figures
figures_folder = os.path.join(output_folder_path, 'figures')
os.makedirs(figures_folder, exist_ok=True)

# === Extract figures ===
wifi_figure_map = extract_all_figures_with_captions(
    pdf_path=pdf_path,
    pdf_name=pdf_name,
    output_folder=figures_folder  # images go here
)

# === Save metadata to top-level output folder ===
import json
metadata_path = os.path.join(output_folder_path, "figure_metadata.json")
with open(metadata_path, "w", encoding="utf-8") as f:
    json.dump(wifi_figure_map, f, indent=2, ensure_ascii=False)

print(f"✅ Saved figure metadata to: {metadata_path}")
print("✅ Sample extracted figures:")
for fig in list(wifi_figure_map.values())[:5]:
    print(fig)
# Out:
# 🔎 Found caption match: Figura 1 — 'vmware vsphere' on page 6
#
# 🔍 [Figura 1_vmware_vsphere] Using provided caption rect on page 6: (232.94679260253906, 598.8972778320312, 541.3529663085938, 624.060302734375)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 242.9937744140625, 538.0449829101562, 608.602294921875), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=608.60, caption_y=598.90
# 📐 Cropped from vector box: figure 1_vmware_vsphere from page 6
# 🔎 Found caption match: Figura 2 — 'vmware nsx – architettura' on page 7
#
# 🔍 [Figura 2_vmware_nsx__architettura] Using provided caption rect on page 7: (208.68649291992188, 501.7381286621094, 479.6080017089844, 526.901123046875)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(118.69999694824219, 177.84307861328125, 476.29998779296875, 511.4430847167969), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=511.44, caption_y=501.74
# 📐 Cropped from vector box: figure 2_vmware_nsx__architettura from page 7
# 🔎 Found caption match: Figura 3 — 'vmware aria' on page 8
#
# 🔍 [Figura 3_vmware_aria] Using provided caption rect on page 8: (240.82760620117188, 593.0310668945312, 539.3330078125, 618.194091796875)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(58.97500991821289, 223.93609619140625, 536.0250244140625, 602.736083984375), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=602.74, caption_y=593.03
# 📐 Cropped from vector box: figure 3_vmware_aria from page 8
# 🔎 Found caption match: Figura 4 — 'infrastruttura fisica cloud insiel' on page 9
#
# 🔍 [Figura 4_infrastruttura_fisica_cloud_insiel] Using provided caption rect on page 9: (195.908203125, 623.1803588867188, 541.3529663085938, 648.3433837890625)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 389.70709228515625, 538.0449829101562, 632.885498046875), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=632.89, caption_y=623.18
# 📐 Cropped from vector box: figure 4_infrastruttura_fisica_cloud_insiel from page 9
# 🔎 Found caption match: Figura 5 — 'tier 1 gateways su nsx' on page 10
#
# 🔍 [Figura 5_tier_1_gateways_su_nsx] Using provided caption rect on page 10: (217.56350708007812, 328.67120361328125, 541.3529663085938, 353.8341979980469)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 260.31927490234375, 538.0449829101562, 338.37628173828125), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=338.38, caption_y=328.67
#    ➤ Rect 2: Rect(56.95500183105469, 369.75750732421875, 538.0449829101562, 685.658447265625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
# 📐 Cropped from vector box: figure 5_tier_1_gateways_su_nsx from page 10
# 🔎 Found caption match: Figura 6 — 'infrastruttura logica cloud insiel' on page 10
#
# 🔍 [Figura 6_infrastruttura_logica_cloud_insiel] Using provided caption rect on page 10: (193.41549682617188, 675.953369140625, 541.3529663085938, 701.1163940429688)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 260.31927490234375, 538.0449829101562, 338.37628173828125), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 2: Rect(56.95500183105469, 369.75750732421875, 538.0449829101562, 685.658447265625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=685.66, caption_y=675.95
# 📐 Cropped from vector box: figure 6_infrastruttura_logica_cloud_insiel from page 10
# 🔎 Found caption match: Figura 7 — 'accesso al cloud insiel – inserimento user name' on page 11
#
# 🔍 [Figura 7_accesso_al_cloud_insiel__inserimento_user_name] Using provided caption rect on page 11: (155.23190307617188, 643.8551025390625, 541.3529663085938, 669.01806640625)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(174.5363006591797, 210.37850952148438, 420.4637145996094, 210.37850952148438), lw=1.0, fill=None, stroke=(0.0, 0.0, 1.0)
#      ❌ Failed visual filter
#    ➤ Rect 2: Rect(56.95500183105469, 296.3759765625, 538.0449829101562, 653.56005859375), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=653.56, caption_y=643.86
# 📐 Cropped from vector box: figure 7_accesso_al_cloud_insiel__inserimento_user_name from page 11
# 🔎 Found caption match: Figura 8 — 'accesso al cloud insiel - inserimento password' on page 12
#
# 🔍 [Figura 8_accesso_al_cloud_insiel_-_inserimento_password] Using provided caption rect on page 12: (158.02000427246094, 485.2046203613281, 541.3529663085938, 510.36749267578125)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 122.85906982421875, 538.0449829101562, 494.9095764160156), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=494.91, caption_y=485.20
#    ➤ Rect 2: Rect(56.95000076293945, 553.7828369140625, 538.0399780273438, 719.5027465820312), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
# 📐 Cropped from vector box: figure 8_accesso_al_cloud_insiel_-_inserimento_password from page 12
# 🔎 Found caption match: Figura 9 — 'cloud insiel - schermata principale' on page 12
#
# 🔍 [Figura 9_cloud_insiel_-_schermata_principale] Using provided caption rect on page 12: (187.0142059326172, 709.7976684570312, 541.3479614257812, 734.960693359375)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 122.85906982421875, 538.0449829101562, 494.9095764160156), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 2: Rect(56.95000076293945, 553.7828369140625, 538.0399780273438, 719.5027465820312), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=719.50, caption_y=709.80
# 📐 Cropped from vector box: figure 9_cloud_insiel_-_schermata_principale from page 12
# 🔎 Found caption match: Figura 10 — 'richiesta credenziali insiel' on page 13
#
# 🔍 [Figura 10_richiesta_credenziali_insiel] Using provided caption rect on page 13: (203.9501953125, 424.13201904296875, 421.9580383300781, 449.29498291015625)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(93.60467529296875, 185.777587890625, 501.39532470703125, 185.777587890625), lw=1.0, fill=None, stroke=(0.0, 0.0, 1.0)
#      ❌ Failed visual filter
#    ➤ Rect 2: Rect(176.35000610351562, 230.5369873046875, 418.6500244140625, 433.83697509765625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=433.84, caption_y=424.13
# 📐 Cropped from vector box: figure 10_richiesta_credenziali_insiel from page 13
# 🔎 Found caption match: Figura 11 — 'cambio password insiel' on page 14
#
# 🔍 [Figura 11_cambio_password_insiel] Using provided caption rect on page 14: (210.6273956298828, 488.96881103515625, 535.9158325195312, 514.1317138671875)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect
lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=730.98, caption_y=721.27
# 📐 Cropped from vector box: figure 22_risorse_computazionali from page 21
# 🔎 Found caption match: Figura 23 — 'deployments menu' on page 22
#
# 🔍 [Figura 23_deployments_menu] Using provided caption rect on page 22: (216.2003936767578, 368.3802185058594, 384.0580139160156, 394.510498046875)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(214.25, 216.085205078125, 380.75, 378.085205078125), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=378.09, caption_y=368.38
#    ➤ Rect 2: Rect(56.95000076293945, 489.6523132324219, 538.0399780273438, 595.6719970703125), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
# 📐 Cropped from vector box: figure 23_deployments_menu from page 22
# 🔎 Found caption match: Figura 24 — 'deployments' on page 22
#
# 🔍 [Figura 24_deployments] Using provided caption rect on page 22: (232.39700317382812, 585.9671020507812, 541.3479614257812, 612.0973510742188)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(214.25, 216.085205078125, 380.75, 378.085205078125), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 2: Rect(56.95000076293945, 489.6523132324219, 538.0399780273438, 595.6719970703125), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=595.67, caption_y=585.97
# 📐 Cropped from vector box: figure 24_deployments from page 22
# 🔎 Found caption match: Figura 25 — 'deployment – status' on page 23
#
# 🔍 [Figura 25_deployment__status] Using provided caption rect on page 23: (212.53199768066406, 282.1261901855469, 385.5267639160156, 308.2565002441406)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(218.68359375, 205.335205078125, 376.3164978027344, 291.8312072753906), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=291.83, caption_y=282.13
#    ➤ Rect 2: Rect(56.95000076293945, 365.1377868652344, 538.0399780273438, 595.5654907226562), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 3: Rect(224.75, 687.8681640625, 370.25, 741.1181640625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
# 📐 Cropped from vector box: figure 25_deployment__status from page 23
# 🔎 Found caption match: Figura 26 — 'deployment – dettagli' on page 23
#
# 🔍 [Figura 26_deployment__dettagli] Using provided caption rect on page 23: (209.17239379882812, 585.8604736328125, 541.3479614257812, 611.9909057617188)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(218.68359375, 205.335205078125, 376.3164978027344, 291.8312072753906), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 2: Rect(56.95000076293945, 365.1377868652344, 538.0399780273438, 595.5654907226562), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=595.57, caption_y=585.86
#    ➤ Rect 3: Rect(224.75, 687.8681640625, 370.25, 741.1181640625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
# 📐 Cropped from vector box: figure 26_deployment__dettagli from page 23
# 🔎 Found caption match: Figura 27 — 'deployment – menu contestuale' on page 23
#
# 🔍 [Figura 27_deployment__menu_contestuale] Using provided caption rect on page 23: (182.88890075683594, 731.4132080078125, 415.1692199707031, 757.5435180664062)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(218.68359375, 205.335205078125, 376.3164978027344, 291.8312072753906), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 2: Rect(56.95000076293945, 365.1377868652344, 538.0399780273438, 595.5654907226562), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 3: Rect(224.75, 687.8681640625, 370.25, 741.1181640625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=741.12, caption_y=731.41
# 📐 Cropped from vector box: figure 27_deployment__menu_contestuale from page 23
# 🔎 Found caption match: Figura 28 — 'deployment – edit' on page 24
#
# 🔍 [Figura 28_deployment__edit] Using provided caption rect on page 24: (218.95309448242188, 424.8976135253906, 541.3479614257812, 451.02801513671875)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(237.2039031982422, 518.591552734375, 442.572998046875, 518.591552734375), lw=1.0, fill=None, stroke=(0.0, 0.0, 1.0)
#      ❌ Failed visual filter
#    ➤ Rect 2: Rect(56.95000076293945, 164.09710693359375, 538.0399780273438, 434.60260009765625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=434.60, caption_y=424.90
# 📐 Cropped from vector box: figure 28_deployment__edit from page 24
# 🔎 Found caption match: Figura 29 — 'deployment – dettaglio' on page 25
#
# 🔍 [Figura 29_deployment__dettaglio] Using provided caption rect on page 25: (205.8126983642578, 367.1605224609375, 541.3479614257812, 393.2908935546875)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect
lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 3: Rect(56.95500183105469, 423.8843994140625, 538.0449829101562, 494.697265625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
# 📐 Cropped from vector box: figure 80_vmware_nsx_-_servizi_-_dettaglio_servizio from page 55
# 🔎 Found caption match: Figura 81 — 'vmware nsx - servizi – operazioni sui servizi' on page 55
#
# 🔍 [Figura 81_vmware_nsx_-_servizi__operazioni_sui_servizi] Using provided caption rect on page 55: (162.08740234375, 289.7337951660156, 435.69268798828125, 314.89678955078125)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 122.85906982421875, 538.0449829101562, 167.36558532714844), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 2: Rect(205.6999969482422, 226.23876953125, 389.29998779296875, 299.43878173828125), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=299.44, caption_y=289.73
#    ➤ Rect 3: Rect(56.95500183105469, 423.8843994140625, 538.0449829101562, 494.697265625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
# 📐 Cropped from vector box: figure 81_vmware_nsx_-_servizi__operazioni_sui_servizi from page 55
# 🔎 Found caption match: Figura 82 — 'vmware nsx - servizi - creazione di un nuovo servizio.' on page 55
#
# 🔍 [Figura 82_vmware_nsx_-_servizi_-_creazione_di_un_nuovo_servizio] Using provided caption rect on page 55: (139.59719848632812, 484.9923095703125, 541.3529663085938, 510.1553039550781)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 122.85906982421875, 538.0449829101562, 167.36558532714844), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 2: Rect(205.6999969482422, 226.23876953125, 389.29998779296875, 299.43878173828125), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 3: Rect(56.95500183105469, 423.8843994140625, 538.0449829101562, 494.697265625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=494.70, caption_y=484.99
# 📐 Cropped from vector box: figure 82_vmware_nsx_-_servizi_-_creazione_di_un_nuovo_servizio from page 55
# 🔎 Found caption match: Figura 83 — 'vmware nsx - servizi - creazione di un nuovo singolo servizio.' on page 56
#
# 🔍 [Figura 83_vmware_nsx_-_servizi_-_creazione_di_un_nuovo_singolo_servizi] Using provided caption rect on page 56: (120.43209838867188, 392.83331298828125, 541.3529663085938, 417.9963073730469)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 122.85906982421875, 538.0449829101562, 402.5383605957031), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=402.54, caption_y=392.83
#    ➤ Rect 2: Rect(56.95500183105469, 554.198486328125, 538.0449829101562, 671.1488647460938), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
# 📐 Cropped from vector box: figure 83_vmware_nsx_-_servizi_-_creazione_di_un_nuovo_singolo_servizi from page 56
# 🔎 Found caption match: Figura 84 — 'vmware nsx – gruppi' on page 56
#
# 🔍 [Figura 84_vmware_nsx__gruppi] Using provided caption rect on page 56: (217.6708984375, 661.4437866210938, 541.3529663085938, 686.6068115234375)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 122.85906982421875, 538.0449829101562, 402.5383605957031), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 2: Rect(56.95500183105469, 554.198486328125, 538.0449829101562, 671.1488647460938), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=671.15, caption_y=661.44
# 📐 Cropped from vector box: figure 84_vmware_nsx__gruppi from page 56
# 🔎 Found caption match: Figura 85 — 'vmware nsx – vm associate al gruppo' on page 57
#
# 🔍 [Figura 85_vmware_nsx__vm_associate_al_gruppo] Using provided caption rect on page 57: (56.70000076293945, 362.7814025878906, 541.3729858398438, 415.2586975097656)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(137.9051055908203, 122.85906982421875, 457.09490966796875, 372.48638916015625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=372.49, caption_y=362.78
#    ➤ Rect 2: Rect(180.27940368652344, 431.3597106933594, 414.7205810546875, 525.751708984375), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 3: Rect(56.95500183105469, 570.87890625, 538.0449829101562, 633.0302124023438), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
# 📐 Cropped from vector box: figure 85_vmware_nsx__vm_associate_al_gruppo from page 57
# 🔎 Found caption match: Figura 86 — 'vmware nsx – modifica gruppo' on page 57
#
# 🔍 [Figura 86_vmware_nsx__modifica_gruppo] Using provided caption rect on page 57: (195.1732940673828, 516.0466918945312, 418.0285949707031, 541.209716796875)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(137.9051055908203, 122.85906982421875, 457.09490966796875, 372.48638916015625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 2: Rect(180.27940368652344, 431.3597106933594, 414.7205810546875, 525.751708984375), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=525.75, caption_y=516.05
#    ➤ Rect 3: Rect(56.95500183105469, 570.87890625, 538.0449829101562, 633.0302124023438), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
# 📐 Cropped from vector box: figure 86_vmware_nsx__modifica_gruppo from page 57
# 🔎 Found caption match: Figura 87 — 'vmware nsx - dettaglio modifica gruppo' on page 57
#
# 🔍 [Figura 87_vmware_nsx_-_dettaglio_modifica_gruppo] Using provided caption rect on page 57: (173.22999572753906, 623.3251953125, 541.3529663085938, 648.4881591796875)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(137.9051055908203, 122.85906982421875, 457.09490966796875, 372.48638916015625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 2: Rect(180.27940368652344, 431.3597106933594, 414.7205810546875, 525.751708984375), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=525.75, caption_y=623.33
#    ➤ Rect 3: Rect(56.95500183105469, 570.87890625, 538.0449829101562, 633.0302124023438), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=633.03, caption_y=623.33
# 📐 Cropped from vector box: figure 87_vmware_nsx_-_dettaglio_modifica_gruppo from page 57
# 🔎 Found caption match: Figura 88 — 'vmware nsx - criterio gruppo' on page 58
#
# 🔍 [Figura 88_vmware_nsx_-_criterio_gruppo] Using provided caption rect on page 58: (198.78660583496094, 260.4115295410156, 541.3529663085938, 285.57452392578125)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(218.85780334472656, 669.0670776367188, 268.99700927734375, 669.0670776367188), lw=1.0, fill=None, stroke=(0.0, 0.0, 1.0)
#      ❌ Failed visual filter
#    ➤ Rect 2: Rect(227.83290100097656, 682.8130493164062, 293.26361083984375, 682.8130493164062), lw=1.0, fill=None, stroke=(0.0, 0.0, 1.0)
#      ❌ Failed visual filter
#    ➤ Rect 3: Rect(377.0965270996094, 721.760986328125, 445.58331298828125, 721.760986328125), lw=1.0, fill=None, stroke=(0.0, 0.0, 1.0)
#      ❌ Failed visual filter
#    ➤ Rect 4: Rect(515.6823120117188, 760.7088623046875, 538.2999877929688, 760.7088623046875), lw=1.0, fill=None, stroke=(0.0, 0.0, 1.0)
#      ❌ Failed visual filter
#    ➤ Rect 5: Rect(56.70000076293945, 774.4548950195312, 108.68682098388672, 774.4548950195312), lw=1.0, fill=None, stroke=(0.0, 0.0, 1.0)
#      ❌ Failed visual filter
#    ➤ Rect 6: Rect(56.95500183105469, 122.85906982421875, 538.0449829101562, 270.1165771484375), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=270.12, caption_y=260.41
# 📐 Cropped from vector box: figure 88_vmware_nsx_-_criterio_gruppo from page 58
# 🔎 Found caption match: Figura 1 — 'vmware vsphere' on page 64
# ⚠️ Skipping Figura 1 — duplicate caption
# 🔎 Found caption match: Figura 47 — 'virtual machines – dettaglio vm' on page 65
# ⚠️ Skipping Figura 47 — duplicate caption
# ✅ Extracted 90 figures using vector-based cropping
# 📝 Saved metadata to /content/drive/MyDrive/rag_comparison/data/VM_manual/figures/figure_metadata.json
# ✅ Saved figure metadata to: /content/drive/MyDrive/rag_comparison/data/VM_manual/figure_metadata.json
# ✅ Sample extracted figures:
# {'filename': 'VM_manual_figure_1_vmware_vsphere.png', 'figure_id': 'Figura 1_vmware_vsphere', 'caption': 'vmware vsphere', 'page': 6, 'image_page': 6, 'rendered': True, 'source': 'vector_box_crop'}
# {'filename': 'VM_manual_figure_2_vmware_nsx__architettura.png', 'figure_id': 'Figura 2_vmware_nsx__architettura', 'caption': 'vmware nsx – architettura', 'page': 7, 'image_page': 7, 'rendered': True, 'source': 'vector_box_crop'}
# {'filename': 'VM_manual_figure_3_vmware_aria.png', 'figure_id': 'Figura 3_vmware_aria', 'caption': 'vmware aria', 'page': 8, 'image_page': 8, 'rendered': True, 'source': 'vector_box_crop'}
# {'filename': 'VM_manual_figure_4_infrastruttura_fisica_cloud_insiel.png', 'figure_id': 'Figura 4_infrastruttura_fisica_cloud_insiel', 'caption': 'infrastruttura fisica cloud insiel', 'page': 9, 'image_page': 9, 'rendered': True, 'source': 'vector_box_crop'}
# {'filename': 'VM_manual_figure_5_tier_1_gateways_su_nsx.png', 'figure_id': 'Figura 5_tier_1_gateways_su_nsx', 'caption': 'tier 1 gateways su nsx', 'page': 10, 'image_page': 10, 'rendered': True, 'source': 'vector_box_crop'}

# %%
import os

# === Config ===
pdf_path = '/data/wifi_manual/ISTRUZIONE_OPERATIVA_CONFIGURAZIONE_WIFI_ARUBA_REV_01.pdf'
output_folder_path = '/data/wifi_manual'
pdf_name = 'wifi_manual'

# Create subfolder for figures
figures_folder = os.path.join(output_folder_path, 'figures')
os.makedirs(figures_folder, exist_ok=True)

# === Extract figures ===
wifi_figure_map = extract_all_figures_with_captions(
    pdf_path=pdf_path,
    pdf_name=pdf_name,
    output_folder=figures_folder  # images go here
)

# === Save metadata to top-level output folder ===
import json
metadata_path = os.path.join(output_folder_path, "figure_metadata.json")
with open(metadata_path, "w", encoding="utf-8") as f:
    json.dump(wifi_figure_map, f, indent=2, ensure_ascii=False)

print(f"✅ Saved figure metadata to: {metadata_path}")
print("✅ Sample extracted figures:")
for fig in list(wifi_figure_map.values())[:5]:
    print(fig)
# Out:
# 🔎 Found caption match: Figura 1 — 'diagramma logico infrastruttura wi-fi' on page 6
#
# 🔍 [Figura 1_diagramma_logico_infrastruttura_wi-fi] Using provided caption rect on page 6: (183.8769989013672, 535.572998046875, 541.3529663085938, 560.7359619140625)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(64.3189926147461, 412.41070556640625, 162.60940551757812, 467.6781921386719), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 2: Rect(64.3189926147461, 412.4107666015625, 162.6094207763672, 467.6783142089844), lw=1.0, fill=None, stroke=(0.35686275362968445, 0.6078431606292725, 0.8352941274642944)
#      ❌ Failed visual filter
#    ➤ Rect 3: Rect(414.4507141113281, 244.82012939453125, 525.0529174804688, 381.6885070800781), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 4: Rect(414.4507141113281, 244.82009887695312, 525.0527954101562, 381.68853759765625), lw=1.0, fill=None, stroke=(0.35686275362968445, 0.6078431606292725, 0.8352941274642944)
#      ❌ Failed visual filter
#    ➤ Rect 5: Rect(297.7536926269531, 244.82012939453125, 396.0440979003906, 381.6885070800781), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect
lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
# 📐 Cropped from vector box: figure 2_accesso_al_mobility_conductor from page 7
# 🔎 Found caption match: Figura 3 — 'schermata principale del 'mobility conductor'' on page 7
#
# 🔍 [Figura 3_schermata_principale_del_mobility_conductor] Using provided caption rect on page 7: (165.1024932861328, 720.3648681640625, 541.3529663085938, 745.52783203125)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(211.6075897216797, 197.17665100097656, 383.3924255371094, 197.17665100097656), lw=1.0, fill=None, stroke=(0.0, 0.0, 1.0)
#      ❌ Failed visual filter
#    ➤ Rect 2: Rect(56.95500183105469, 214.444091796875, 538.0449829101562, 416.21990966796875), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 3: Rect(56.95500183105469, 502.5851135253906, 538.0449829101562, 730.06982421875), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=730.07, caption_y=720.36
# 📐 Cropped from vector box: figure 3_schermata_principale_del_mobility_conductor from page 7
# 🔎 Found caption match: Figura 4 — 'reti gestite' on page 8
#
# 🔍 [Figura 4_reti_gestite] Using provided caption rect on page 8: (246.65769958496094, 508.6453552246094, 375.0871276855469, 533.8082885742188)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(223.2209014892578, 182.09710693359375, 371.77911376953125, 518.350341796875), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=518.35, caption_y=508.65
# 📐 Cropped from vector box: figure 4_reti_gestite from page 8
# 🔎 Found caption match: Figura 5 — 'statistiche infrastruttura' on page 9
#
# 🔍 [Figura 5_statistiche_infrastruttura] Using provided caption rect on page 9: (215.54200744628906, 400.35052490234375, 541.2088012695312, 425.51348876953125)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(57.09920120239258, 140.85906982421875, 537.9008178710938, 410.05548095703125), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=410.06, caption_y=400.35
# 📐 Cropped from vector box: figure 5_statistiche_infrastruttura from page 9
# 🔎 Found caption match: Figura 6 — 'dati statistici relativi ad uno specifico sito' on page 10
#
# 🔍 [Figura 6_dati_statistici_relativi_ad_uno_specifico_sito] Using provided caption rect on page 10: (173.85989379882812, 413.00152587890625, 541.118896484375, 438.16448974609375)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(57.189090728759766, 195.84307861328125, 537.8109130859375, 422.70648193359375), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=422.71, caption_y=413.00
# 📐 Cropped from vector box: figure 6_dati_statistici_relativi_ad_uno_specifico_sito from page 10
# 🔎 Found caption match: Figura 7 — 'configuration - dettaglio' on page 11
#
# 🔍 [Figura 7_configuration_-_dettaglio] Using provided caption rect on page 11: (213.8892059326172, 429.5506286621094, 541.3529663085938, 454.7135925292969)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 212.15386962890625, 538.0449829101562, 439.25555419921875), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=439.26, caption_y=429.55
# 📐 Cropped from vector box: figure 7_configuration_-_dettaglio from page 11
# 🔎 Found caption match: Figura 8 — 'dettaglio wlan' on page 12
#
# 🔍 [Figura 8_dettaglio_wlan] Using provided caption rect on page 12: (235.8350067138672, 405.42681884765625, 541.3529663085938, 430.58978271484375)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 192.40789794921875, 538.0449829101562, 415.1318054199219), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=415.13, caption_y=405.43
# 📐 Cropped from vector box: figure 8_dettaglio_wlan from page 12
# 🔎 Found caption match: Figura 9 — 'dettaglio vlans' on page 13
#
# 🔍 [Figura 9_dettaglio_vlans] Using provided caption rect on page 13: (233.3227996826172, 410.7729187011719, 541.3529663085938, 435.9358825683594)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 192.40789794921875, 538.0449829101562, 420.4779968261719), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1

# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 302.47442626953125, 538.0449829101562, 492.95623779296875), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 2: Rect(56.95500183105469, 575.6176147460938, 538.0449829101562, 767.291015625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=767.29, caption_y=757.59
# 📐 Cropped from vector box: figure 35_centro_connessioni_di_rete_e_condivisione from page 34
# 🔎 Found caption match: Figura 36 — 'configura connessione o rete' on page 36
#
# 🔍 [Figura 36_configura_connessione_o_rete] Using provided caption rect on page 36: (200.26119995117188, 550.9804077148438, 532.2080078125, 576.143310546875)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(66.10001373291016, 218.6353759765625, 528.9000244140625, 560.6853637695312), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=560.69, caption_y=550.98
# 📐 Cropped from vector box: figure 36_configura_connessione_o_rete from page 36
# 🔎 Found caption match: Figura 37 — 'connetti manualmente a una rete wireless' on page 37
#
# 🔍 [Figura 37_connetti_manualmente_a_una_rete_wireless] Using provided caption rect on page 37: (170.7982940673828, 535.2304077148438, 532.2080078125, 560.393310546875)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(66.10001373291016, 202.8853759765625, 528.9000244140625, 544.9353637695312), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=544.94, caption_y=535.23
# 📐 Cropped from vector box: figure 37_connetti_manualmente_a_una_rete_wireless from page 37
# 🔎 Found caption match: Figura 38 — 'aggiunta di asugi_test4 completata' on page 38
#
# 🔍 [Figura 38_aggiunta_di_asugi_test4_completata] Using provided caption rect on page 38: (180.35400390625, 580.9221801757812, 530.7080078125, 606.085205078125)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(67.60001373291016, 250.82720947265625, 527.4000244140625, 590.627197265625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=590.63, caption_y=580.92
# 📐 Cropped from vector box: figure 38_aggiunta_di_asugi_test4_completata from page 38
# 🔎 Found caption match: Figura 39 — 'proprietà rete wireless - connessione' on page 39
#
# 🔍 [Figura 39_proprietà_rete_wireless_-_connessione] Using provided caption rect on page 39: (181.3524932861328, 532.1961059570312, 441.4580078125, 557.359130859375)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(156.85000610351562, 168.35107421875, 438.1499938964844, 541.9010620117188), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=541.90, caption_y=532.20
# 📐 Cropped from vector box: figure 39_proprietà_rete_wireless_-_connessione from page 39
# 🔎 Found caption match: Figura 40 — 'proprietà rete wireless - sicurezza' on page 40
#
# 🔍 [Figura 40_proprietà_rete_wireless_-_sicurezza] Using provided caption rect on page 40: (189.68020629882812, 546.6920776367188, 441.8330078125, 571.8551025390625)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(156.47500610351562, 182.09710693359375, 438.5249938964844, 556.3970947265625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=556.40, caption_y=546.69
# 📐 Cropped from vector box: figure 40_proprietà_rete_wireless_-_sicurezza from page 40
# 🔎 Found caption match: Figura 41 — 'proprietà peap' on page 41
#
# 🔍 [Figura 41_proprietà_peap] Using provided caption rect on page 41: (233.96240234375, 598.9461059570312, 447.4580078125, 624.109130859375)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(150.85000610351562, 168.35107421875, 444.1499938964844, 608.6510620117188), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=608.65, caption_y=598.95
# 📐 Cropped from vector box: figure 41_proprietà_peap from page 41
# 🔎 Found caption match: Figura 42 — 'proprietà smart card o altro certificato' on page 42
#
# 🔍 [Figura 42_proprietà_smart_card_o_altro_certificato] Using provided caption rect on page 42: (179.96580505371094, 610.4420776367188, 449.7080078125, 635.6051025390625)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(148.60000610351562, 182.09710693359375, 446.3999938964844, 620.1470947265625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=620.15, caption_y=610.44
# 📐 Cropped from vector box: figure 42_proprietà_smart_card_o_altro_certificato from page 42
# 🔎 Found caption match: Figura 43 — 'configurazione selezione certificati' on page 43
#
# 🔍 [Figura 43_configurazione_selezione_certificati] Using provided caption rect on page 43: (56.70000076293945, 645.68408203125, 487.7080078125, 698.1614379882812)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
# 📎 Trying embedded image fallback on caption page (using top-aligned matching)...
# 🔍 Found 2 embedded images with position info on page 43
# 🧪 Caption Y: 645.68408203125
#    ➤ Image bbox: (58.07807922363281, 36.00001525878906, 175.77748107910156, 84.27801513671875)
#    ➤ Image bbox: (110.3499984741211, 209.339111328125, 484.6499938964844, 655.6390991210938)
# 🖼️ Saved embedded image just above caption for figure 43_configurazione_selezione_certificati on page 43
# 🔎 Found caption match: Figura 44 — 'impostazioni avanzate – 802.1x' on page 44
#
# 🔍 [Figura 44_impostazioni_avanzate__8021x] Using provided caption rect on page 44: (196.3524932861328, 586.93408203125, 446.7080078125, 612.0971069335938)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(151.60000610351562, 209.58917236328125, 443.3999938964844, 596.63916015625), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=596.64, caption_y=586.93
# 📐 Cropped from vector box: figure 44_impostazioni_avanzate__8021x from page 44
# 🔎 Found caption match: Figura 45 — 'impostazioni avanzate – 802.11' on page 45
#
# 🔍 [Figura 45_impostazioni_avanzate__80211] Using provided caption rect on page 45: (56.70000076293945, 546.6961059570312, 446.0830078125, 599.1734008789062)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
# 📎 Trying embedded image fallback on caption page (using top-aligned matching)...
# 🔍 Found 3 embedded images with position info on page 45
# 🧪 Caption Y: 546.6961059570312
#    ➤ Image bbox: (58.07807922363281, 36.00001525878906, 175.77748107910156, 84.27801513671875)
#    ➤ Image bbox: (151.97500610351562, 168.10113525390625, 443.0249938964844, 556.651123046875)
# 🖼️ Saved embedded image just above caption for figure 45_impostazioni_avanzate__80211 on page 45
# 🔎 Found caption match: Figura 46 — 'dashboard - overview' on page 46
#
# 🔍 [Figura 46_dashboard_-_overview] Using provided caption rect on page 46: (218.03219604492188, 418.8511047363281, 541.3529663085938, 444.01409912109375)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 200.697998046875, 538.0449829101562, 428.5559997558594), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=428.56, caption_y=418.85
#    ➤ Rect 2: Rect(56.95500183105469, 526.377197265625, 538.0449829101562, 757.6585693359375), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
# 📐 Cropped from vector box: figure 46_dashboard_-_overview from page 46
# 🔎 Found caption match: Figura 47 — 'dashboard - overview - client' on page 46
#
# 🔍 [Figura 47_dashboard_-_overview_-_client] Using provided caption rect on page 46: (199.69970703125, 747.95361328125, 541.3529663085938, 773.1165771484375)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 200.697998046875, 538.0449829101562, 428.5559997558594), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ❌ Failed caption proximity
#    ➤ Rect 2: Rect(56.95500183105469, 526.377197265625, 538.0449829101562, 757.6585693359375), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=757.66, caption_y=747.95
# 📐 Cropped from vector box: figure 47_dashboard_-_overview_-_client from page 46
# 🔎 Found caption match: Figura 48 — 'dashboard - overview - client - dettaglio' on page 47
#
# 🔍 [Figura 48_dashboard_-_overview_-_client_-_dettaglio] Using provided caption rect on page 47: (173.86720275878906, 415.0259094238281, 541.3529663085938, 440.18890380859375)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 195.84307861328125, 538.0449829101562, 424.73089599609375), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=424.73, caption_y=415.03
# 📐 Cropped from vector box: figure 48_dashboard_-_overview_-_client_-_dettaglio from page 47
# 🔎 Found caption match: Figura 49 — 'dashboard - overview - wlans' on page 48
#
# 🔍 [Figura 49_dashboard_-_overview_-_wlans] Using provided caption rect on page 48: (195.81300354003906, 401.3652038574219, 541.3529663085938, 426.5281982421875)
# 🔍 Scanning vector borders on page...
#    ➤ Rect 0: Rect(0.0, 0.0, 595.0, 842.0), lw=1.0, fill=(1.0, 1.0, 1.0), stroke=None
#      ❌ Failed visual filter
#    ➤ Rect 1: Rect(56.95500183105469, 179.806884765625, 538.0449829101562, 411.0701904296875), lw=1.0, fill=None, stroke=(0.0, 0.0, 0.0)
#      ✅ Passed visual filter
#      ✅ Passed caption proximity: y1=411.07, caption_y=401.37
# 📐 Cropped from vector box: figure 49_dashboard_-_overview_-_wlans from page 48
# 🔎 Found caption match: Figura 1 — 'diagramma logico infrastruttura wi-fi' on page 50
# ⚠️ Skipping Figura 1 — duplicate caption
# 🔎 Found caption match: Figura 46 — 'dashboard - overview' on page 51
# ⚠️ Skipping Figura 46 — duplicate caption
# ✅ Extracted 49 figures using vector-based cropping
# 📝 Saved metadata to /content/drive/MyDrive/rag_comparison/data/wifi_manual/figures/figure_metadata.json
# ✅ Saved figure metadata to: /content/drive/MyDrive/rag_comparison/data/wifi_manual/figure_metadata.json
# ✅ Sample extracted figures:
# {'filename': 'wifi_manual_figure_1_diagramma_logico_infrastruttura_wi-fi.png', 'figure_id': 'Figura 1_diagramma_logico_infrastruttura_wi-fi', 'caption': 'diagramma logico infrastruttura wi-fi', 'page': 6, 'image_page': 6, 'rendered': True, 'source': 'vector_box_crop'}
# {'filename': 'wifi_manual_figure_2_accesso_al_mobility_conductor.png', 'figure_id': 'Figura 2_accesso_al_mobility_conductor', 'caption': "accesso al 'mobility conductor'", 'page': 7, 'image_page': 7, 'rendered': True, 'source': 'vector_box_crop'}
# {'filename': 'wifi_manual_figure_3_schermata_principale_del_mobility_conductor.png', 'figure_id': 'Figura 3_schermata_principale_del_mobility_conductor', 'caption': "schermata principale del 'mobility conductor'", 'page': 7, 'image_page': 7, 'rendered': True, 'source': 'vector_box_crop'}
# {'filename': 'wifi_manual_figure_4_reti_gestite.png', 'figure_id': 'Figura 4_reti_gestite', 'caption': 'reti gestite', 'page': 8, 'image_page': 8, 'rendered': True, 'source': 'vector_box_crop'}
# {'filename': 'wifi_manual_figure_5_statistiche_infrastruttura.png', 'figure_id': 'Figura 5_statistiche_infrastruttura', 'caption': 'statistiche infrastruttura', 'page': 9, 'image_page': 9, 'rendered': True, 'source': 'vector_box_crop'}

# %% [markdown]
# # Semantic chunking w/ llama parse + gpt 4 and instructor (?)

# %%
# 📦 Install LlamaParse client (if not already installed)
# !pip install llama-parse --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.1/253.1 kB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.7/808.7 kB 45.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 48.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.2/129.2 kB 10.8 MB/s eta 0:00:00

# %%
def parse_pdf_llama_no_image_text(filename: str, output_path: str):
    print(f"📄 Parsing '{filename}' (OCR=OFF, image‑text filtered)...")

    parser = LlamaParse(
        api_key=os.environ["LLAMA_CLOUD_API_KEY"],
        result_type="markdown",
        include_metadata=True,
        include_images=False,
        parse_mode="parse_page_with_agent",
        disable_image_extraction=True,
        disable_ocr=True,
        chunking_strategy="hierarchical",
        auto_title_generation=False,
        infer_table_structures=False,
        num_workers=4
    )

    # 1) load everything
    documents = parser.load_data(filename)

    # 2) filter out any chunks that came from an image
    filtered = []
    for doc in documents:
        # you may need to tweak the key depending on your LlamaParse version:
        # common keys are "block_type" or "source_type"
        if doc.metadata.get("block_type") != "image":
            filtered.append(doc)

    # 3) join and save only the filtered text
    md_text = "\n\n".join([d.text for d in filtered])

    with open(output_path, "w", encoding="utf-8") as f:
        f.write(md_text)

    print(f"✅ Saved filtered markdown to: {output_path}")
    return md_text

# %%
import nest_asyncio
nest_asyncio.apply()

import os
from llama_parse import LlamaParse
from IPython.display import Markdown, display

# ✅ STEP 1: Set API Key
os.environ["LLAMA_CLOUD_API_KEY"] = LLAMA_CLOUD_API_KEY
# Usage
filename    = '/data/wifi_manual/ISTRUZIONE_OPERATIVA_CONFIGURAZIONE_WIFI_ARUBA_REV_01.pdf'
output_path = os.path.join(
    os.path.dirname(filename),
    os.path.basename(filename).replace(".pdf", "_parsed_no_image_llm.md")
)

md_result = parse_pdf_llama_no_image_text(filename, output_path)

# Preview first bit
display(Markdown(md_result[:2000]))
# Out:
# 📄 Parsing '/content/drive/MyDrive/rag_comparison/data/wifi_manual/ISTRUZIONE_OPERATIVA_CONFIGURAZIONE_WIFI_ARUBA_REV_01.pdf' (OCR=OFF, image‑text filtered)...
# Started parsing the file under job_id 230acbc0-bd1d-4414-9673-434e700d0671
# ✅ Saved filtered markdown to: /content/drive/MyDrive/rag_comparison/data/wifi_manual/ISTRUZIONE_OPERATIVA_CONFIGURAZIONE_WIFI_ARUBA_REV_01_parsed_no_image_llm.md
# Configurazione Wi-Fi Aruba:
# access point e terminali       IO_XX_00_XX
#
# Pagina 1 di 51
#
# ISTRUZIONE OPERATIVA           14/10/2024
#
# # CONFIGURAZIONE WI-FI ARUBA: ACCESS POINT E TERMINALI
#
# ## MATRICE DELLE REVISIONI
#
# | REVISIONE | DATA       | DESCRIZIONE                          | REDAZIONE        | VERIFICATA              | APPROVATA     |
# | --------- | ---------- | ------------------------------------ | ---------------- | ----------------------- | ------------- |
# | 00        | 14.10.2024 | 1a emissione                         | Gruppo di lavoro | RSGI/RQ/RSPPGA/ RSTRUTT | DG/DS/DA/ DSS |
# | 01        | 31.10.2024 | Modifica Par.4, Par.5.1.1, Par.5.1.4 | Gruppo di lavoro | RSGI/RQ/RSPPGA/ RSTRUTT | DG/DS/DA/ DSS |
#
#
# Configurazione Wi-Fi Aruba:
# access point e terminali          IO_XX_00_XX
# Pagina 2 di 51
# ISTRUZIONE OPERATIVA              14/10/2024
#
# ## GRUPPO DI LAVORO PER LA REDAZIONE
#
# | Cognome e nome   | Qualifica             | Struttura di appartenenza |
# | ---------------- | --------------------- | ------------------------- |
# | Predonzan Tomaso | Network administrator | ASUGI                     |
# | Monti Maurizio   | Network administrator | ASUGI                     |
# | Chiffi Francesco | System Senior Expert  | BV-Tech                   |
#
#
# Configurazione Wi-Fi Aruba:
# access point e terminali IO_XX_00_XX
# Pagina 3 di 51
# ISTRUZIONE OPERATIVA 14/10/2024
#
# # INDICE
#
# 1. SCOPO ..........................................................................................................................4
# 2. AMBITO DI APPLICAZIONE..........................................................................................4
# 3. ACRONIMI E DEFINIZIONI ...........................................................................................4
# 4. RESPONSABILITA'........................................................................................................4
# 5. MODALITÀ ESECUTIVE ...............................................................................................5

# %%
import nest_asyncio
nest_asyncio.apply()

import os
from llama_parse import LlamaParse
from IPython.display import Markdown, display

# ✅ STEP 1: Set API Key
os.environ["LLAMA_CLOUD_API_KEY"] = LLAMA_CLOUD_API_KEY
# Usage
filename    = '/data/VM_manual/ISTRUZIONE_OPERATIVA_CREAZIONE_VM_CLOUD_INSIEL_REV_00.pdf'
output_path = os.path.join(
    os.path.dirname(filename),
    os.path.basename(filename).replace(".pdf", "_parsed_no_image_llm.md")
)

md_result = parse_pdf_llama_no_image_text(filename, output_path)

# Preview first bit
display(Markdown(md_result[:2000]))
# Out:
# 📄 Parsing '/content/drive/MyDrive/rag_comparison/data/VM_manual/ISTRUZIONE_OPERATIVA_CREAZIONE_VM_CLOUD_INSIEL_REV_00.pdf' (OCR=OFF, image‑text filtered)...
# Started parsing the file under job_id ceb65419-0903-4556-a538-d7b07a9327f6
# .✅ Saved filtered markdown to: /content/drive/MyDrive/rag_comparison/data/VM_manual/ISTRUZIONE_OPERATIVA_CREAZIONE_VM_CLOUD_INSIEL_REV_00_parsed_no_image_llm.md
# |                               |                              |                |
# | ----------------------------- | ---------------------------- | -------------- |
# | !ASUGI logo | Creazione VM su Cloud INSIEL | IO\_XX\_00\_XX |
# | Pagina 1 di 66                |                              |                |
# | ISTRUZIONE OPERATIVA          |                              | 22/10/2024     |
#
# # CREAZIONE VM SU CLOUD INSIEL
#
# | MATRICE DELLE REVISIONI<br/>REVISION | MATRICE DELLE REVISIONI<br/>DATA | MATRICE DELLE REVISIONI<br/>DESCRIZION | MATRICE DELLE REVISIONI<br/>REDAZION | MATRICE DELLE REVISIONI<br/>VERIFICATA | MATRICE DELLE REVISIONI<br/>APPROVATA |
# | ------------------------------------ | -------------------------------- | -------------------------------------- | ------------------------------------ | -------------------------------------- | ------------------------------------- |
# | 00                                   | 22.10.2024                       | 1a emissione                           | Gruppo di lavoro                     | RSGI/RQ/RSPPGA/ RSTRUTT                | DG/DS/DA/ DSS                         |
#
#
# Creazione VM su Cloud INSIEL              IO_XX_00_XX
#
# Pagina 2 di 66
#
# ISTRUZIONE OPERATIVA               22/10/2024
#
# ## GRUPPO DI LAVORO PER LA REDAZIONE
#
# | Cognome e nome   | Qualifica            | Struttura di appartenenza |
# | ---------------- | -------------------- | ------------------------- |
# | Jarc Borut       |                      | ASUGI                     |
# | Chiffi Francesco | System Senior Expert | BV-Tech                   |
#
#
# # Creazione VM su Cloud INSIEL
#
# IO_XX_00_XX
# Pagina 3 di 66
# ISTRUZIONE OPERATIVA
# 22/10/2024
#
# ## INDICE
#
# 1. SCOPO ..........................................................................................................................5
# 2. AMBITO DI APPLICAZIONE..........................................................................................5
# 3. ACRONIMI E DEFINIZIONI .....................................

# %%
import re

# ─── Artifact Stripper ───────────────────────────────────
def strip_artifacts(md_text: str) -> str:
    # 1) Remove mermaid code fences
    md_text = re.sub(r'```mermaid\b.*?```', '', md_text, flags=re.DOTALL|re.IGNORECASE)
    # 2) Drop any fenced code blocks (```...```)
    md_text = re.sub(r'```[\s\S]*?```', '', md_text)
    # 3) Remove ASCII‑tree lines
    md_text = re.sub(r'(?m)^[ \t]*(?:[├└│].*|\+--.*)$', '', md_text)
    # 4) Remove pure markdown table rows
    md_text = re.sub(r'(?m)^\|.*\|\s*$', '', md_text)
    return md_text

# ─── Split into Pages ───────────────────────────────────
def split_into_pages(md_text: str) -> list[tuple[int, str]]:
    """
    Splits the full MD by 'Pagina X di Y', returns [(X, chunk), …].
    Works regardless of total page count (Y).
    """
    pattern = re.compile(
        r'(Pagina\s+(\d+)\s+di\s+\d+.*?)(?=Pagina\s+\d+\s+di\s+\d+|\Z)',
        flags=re.DOTALL | re.IGNORECASE
    )
    chunks = pattern.findall(md_text)

    pages = []
    for full_block, page_num in chunks:
        pages.append((int(page_num), full_block))
    return pages


# ─── TOC Extractor from Index Page ──────────────────────────
def extract_sections_from_index_pages(md_text: str, page_nums: list[int]) -> set[str]:
    """
    Extracts section numbers (e.g. '5', '5.1', '5.1.3.1') from multiple index pages.
    """
    pages = split_into_pages(md_text)
    blocks = [b for num, b in pages if num in page_nums]

    if not blocks:
        raise ValueError(f"No index pages found for {page_nums}")

    nums = set()
    for block in blocks:
        for line in block.splitlines():
            m = re.match(r'^\s*(\d+(?:\.\d+)*)\.', line)
            if m:
                nums.add(m.group(1))
    return nums


# # ─── Heading Promoter ───────────────────────────────────

def promote_numeric_headings(parsed_md: str, valid_sections: set[str]) -> str:
    """
    Fixes heading levels by aligning them with their numeric prefix.
    Strictly respects the TOC: only promotes headings with numbers in `valid_sections`.
    """
    pattern = re.compile(
        r'^(?P<hashes>#{0,6}\s*)?(?P<num>\d+(?:\.\d+)*)(?:\.)?\s+(?P<title>.*)$',
        re.MULTILINE
    )

    def _repl(m):
        hashes = m.group("hashes") or ''
        num = m.group("num")
        title = m.group("title").strip()

        # ✅ Strict TOC check
        if num not in valid_sections:
            return m.group(0)

        # Skip if it ends with a colon (likely not a real heading)
        if title.endswith(':'):
            return m.group(0)

        # Skip if mostly lowercase (to avoid promoting body text)
        letters = re.findall(r'[A-Za-z]', title)
        if letters:
            lower_frac = sum(1 for c in letters if c.islower()) / len(letters)
            if lower_frac > 0.4:
                return m.group(0)

        # ✅ Compute correct level from the section number
        level = num.count('.') + 1
        return f"{'#' * level} {num} {title}"

    return pattern.sub(_repl, parsed_md)



# ─── Page Processor (updated) ─────────────────────────────────────
def process_page(page_md: str, page_num: int, valid_sections: set[str], header_skip_patterns: list[re.Pattern]) -> str:
    lines = page_md.splitlines()
    out = []
    page_line = None
    date_str = None

    for L in lines:
        # Skip matching header lines
        if any(pat.match(L) for pat in header_skip_patterns):
            m_dt = re.search(r'ISTRUZIONE OPERATIVA.*?([0-9]{2}/[0-9]{2}/[0-9]{4})', L, flags=re.IGNORECASE)
            if m_dt:
                date_str = m_dt.group(1)
            continue
        # Match page number line
        m_pg = re.match(r'^\s*Pagina\s+(\d+)\s+di\s+(\d+)', L, flags=re.IGNORECASE)
        if m_pg:
            page_num_str = m_pg.group(1)
            total_pages = m_pg.group(2)
            page_line = f"*Pagina {page_num_str} di {total_pages}"
            continue

        out.append(L)

    # Insert metadata line at top if we have it
    if page_line:
        meta = page_line
        if date_str:
            meta += f" ({date_str})*"
        # Surround with blank lines to force block separation
        out.insert(0, '')         # blank line above
        out.insert(1, meta)       # the page metadata
        out.insert(2, '')         # blank line below



    body = "\n".join(out)

    if page_num > 2:
        body = strip_artifacts(body)

    body = promote_numeric_headings(body, valid_sections)
    return body

# %%
wifi_skip_patterns = [
    re.compile(r'^\s*Configurazione Wi-Fi Aruba:', re.IGNORECASE),
    re.compile(r'^\s*access point e terminali', re.IGNORECASE),
    re.compile(r'^\s*ISTRUZIONE OPERATIVA\s*\d{2}/\d{2}/\d{4}', re.IGNORECASE),
]

vm_skip_patterns = [
    re.compile(r'^\s*Creazione VM su Cloud INSIEL.*$', re.IGNORECASE),
    re.compile(r'^\s*ISTRUZIONE OPERATIVA\s*\d{2}/\d{2}/\d{4}', re.IGNORECASE),
]

# %%
md_path = "/data/wifi_manual/ISTRUZIONE_OPERATIVA_CONFIGURAZIONE_WIFI_ARUBA_REV_01_parsed_no_image_llm.md"
output_path = "/data/wifi_manual/ISTRUZIONE_OPERATIVA_CONFIGURAZIONE_WIFI_ARUBA_REV_01_cleaned.md"

# 1) Load raw parsed MD
with open(md_path, 'r', encoding='utf-8') as f:
    raw_md = f.read()


# 2) Extract true section numbers from the INDICE on page 3
toc_sections = extract_sections_from_index_pages(raw_md, page_nums=[3])
print("Valid sections:", sorted(toc_sections)[:10], "…")

# 3) Split & process each page
pages = split_into_pages(raw_md)
processed = [
    process_page(chunk, num, toc_sections, header_skip_patterns=wifi_skip_patterns)
    for num, chunk in pages
]

# 4) Rejoin & save
final_md = "\n\n".join(processed)
with open(output_path, 'w', encoding='utf-8') as f:
    f.write(final_md)

print("✅ Cleaned Markdown written to", output_path)
# Out:
# Valid sections: ['1', '10', '2', '3', '4', '5', '5.1', '5.1.1', '5.1.2', '5.1.3'] …
# ✅ Cleaned Markdown written to /content/drive/MyDrive/rag_comparison/data/wifi_manual/ISTRUZIONE_OPERATIVA_CONFIGURAZIONE_WIFI_ARUBA_REV_01_cleaned.md

# %%
md_path = "/data/VM_manual/ISTRUZIONE_OPERATIVA_CREAZIONE_VM_CLOUD_INSIEL_REV_00_parsed_no_image_llm.md"
output_path = "/data/VM_manual/ISTRUZIONE_OPERATIVA_CREAZIONE_VM_CLOUD_INSIEL_REV_00_cleaned.md"

# 1) Load raw parsed MD
with open(md_path, 'r', encoding='utf-8') as f:
    raw_md = f.read()


# 2) Extract true section numbers from the INDICE on page 3
toc_sections = extract_sections_from_index_pages(raw_md, page_nums=[3, 4])
print("Valid sections:", sorted(toc_sections)[:10], "…")

# 3) Split & process each page
pages = split_into_pages(raw_md)
processed = [
    process_page(chunk, num, toc_sections, header_skip_patterns=vm_skip_patterns)
    for num, chunk in pages
]

# 4) Rejoin & save
final_md = "\n\n".join(processed)
with open(output_path, 'w', encoding='utf-8') as f:
    f.write(final_md)

print("✅ Cleaned Markdown written to", output_path)
# Out:
# Valid sections: ['1', '2', '3', '4', '5', '5.1', '5.1.1', '5.1.2', '5.1.3', '5.2'] …
# ✅ Cleaned Markdown written to /content/drive/MyDrive/rag_comparison/data/VM_manual/ISTRUZIONE_OPERATIVA_CREAZIONE_VM_CLOUD_INSIEL_REV_00_cleaned.md

# %%
# !pip install openai instructor --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.6/345.6 kB 10.9 MB/s eta 0:00:00

# %%
import re
import os
from openai import OpenAI
import instructor
from pydantic import BaseModel, Field
from typing import List, Optional, Dict
from tqdm import tqdm


class FigureMetadata(BaseModel):
    figure_id: str = Field(..., description="Unique identifier for the figure")
    filename: str = Field(..., description="Name of the image file")
    caption: str = Field(..., description="Caption text for the figure")
    page: int = Field(..., description="Page number where the figur caption is located")
    image_page: int = Field(..., description="Page number where the image is located")
    rendered: bool = Field(..., description="Whether the image has been rendered")
    source: str = Field(..., description="Source of the image (e.g., 'vector_box_crop')")


class SemanticChunk(BaseModel):
    section_number: str = Field(..., description="Hierarchical numeric section (e.g., 5.1.3.1.3)")
    section_title: str = Field(..., description="Concise and meaningful title for the section")
    page_numbers: List[int] = Field(..., description="Page numbers included in the chunk")
    content: str = Field(..., description="Full markdown content of the chunk")
    parent_topics: List[str] = Field(..., description="Ordered list of parent section titles")
    document: str = Field(..., description="Name or identifier of the document")
    chunk_summary: str = Field(..., description="A summary of the chunk content")
    figures: Optional[List[FigureMetadata]] = Field(default_factory=list, description="Figures referenced explicitly in this chunk")

class ChunkSet(BaseModel):
    chunks: List[SemanticChunk] = Field(..., description="List of semantic chunks")

class SummaryOnlyChunk(BaseModel):
    chunk_summary: str = Field(..., description="A summary of the chunk content")

# %%
def summarize_chunks(chunks: List[SemanticChunk]) -> List[SemanticChunk]:
    enriched = []

    for chunk in tqdm(chunks, desc="Summarizing chunks"):
        figure_count = len(chunk.figures)
        figure_desc = ""
        if figure_count:
            figure_titles = ", ".join([f.caption for f in chunk.figures])
            figure_desc = f"\nThis section includes {figure_count} figure(s): {figure_titles}."

        parent_path = " > ".join(chunk.parent_topics + [chunk.section_title])

        prompt = f"""
You are helping document a technical manual. Below is a markdown section titled:

📌 {parent_path}

Please write a clear, concise **summary** of this section for retrieval-augmented systems.

Guidelines:
- Summarize the purpose of the section
- Note any configuration steps, troubleshooting, or systems mentioned
- If figures are included, mention how they support the content
{figure_desc}

Markdown content:
{chunk.content}
"""

        try:
            summary_obj = client.chat.completions.create(
                model="gpt-4-turbo",
                response_model=SummaryOnlyChunk,
                messages=[{"role": "user", "content": prompt}],
                temperature=0.3,
            )

            chunk.chunk_summary = summary_obj.chunk_summary

        except Exception as e:
            print(f"❌ Failed to summarize section {chunk.section_number}: {e}")
            chunk.chunk_summary = ""

        enriched.append(chunk)

    return enriched

# %%
def parse_heading_structure(md_text: str) -> List[Dict]:
    headings = []
    lines = md_text.splitlines()

    for idx, line in enumerate(lines):
        match = re.match(r'^(#{1,6})\s+(.*)', line)
        if match:
            level = len(match.group(1))
            raw_text = match.group(2).strip()

            # ❌ Skip TOC-style headings with dotted lines ending in numbers
            if re.search(r'\.{5,}\s*\d+\s*$', raw_text):
                continue

            sec_match = re.match(r'^([\d\.]+)\.?\s*(.*)', raw_text)
            if not sec_match:
                continue

            section_number = sec_match.group(1)
            title = sec_match.group(2).strip()

            headings.append({
                "line_number": idx,
                "level": level,
                "raw": line.strip(),
                "text": raw_text,
                "section_number": section_number,
                "title": title
            })

    return headings

# %%
def resolve_parent_topics(headings: List[Dict]) -> List[Dict]:
    """
    Adds 'parent_topics' to each heading based on heading level nesting.
    """
    stack = []
    result = []

    for heading in headings:
        level = heading["level"]

        # Truncate stack to correct depth
        stack = [h for h in stack if h["level"] < level]

        # Current heading is added to the stack
        stack.append(heading)

        # Extract parent topics (everything in stack except the current one)
        parent_topics = [h["title"] for h in stack[:-1]]

        heading_with_parents = heading.copy()
        heading_with_parents["parent_topics"] = parent_topics
        result.append(heading_with_parents)

    return result

# %%
from difflib import get_close_matches

from typing import List, Dict, Optional

def generate_semantic_chunks_from_headings(
    md_text: str,
    headings: List[Dict],
    document_name: str,
    line_to_page: Dict[int, int],
    original_lines: Optional[List[str]] = None
) -> List[Dict]:
    """
    Given full markdown text and a parsed heading list (with parent_topics),
    extracts semantic chunks with metadata including page number ranges.
    """
    lines = md_text.splitlines()
    chunks = []

    def get_chunk_page_range(start: int, end: int, mapping: Dict[int, int]) -> List[int]:
        pages = [mapping.get(i) for i in range(start, end)]
        return sorted(set(p for p in pages if p is not None))

    for i, heading in enumerate(headings):
        start_line = heading["line_number"]
        end_line = headings[i + 1]["line_number"] if i + 1 < len(headings) else len(lines)

        chunk_lines = lines[start_line:end_line]
        chunk_text = "\n".join(chunk_lines).strip()

        page_numbers = get_chunk_page_range(start_line, end_line, line_to_page)

        chunks.append({
            "section_number": heading["section_number"],
            "section_title": heading["title"],
            "page_numbers": page_numbers,
            "content": chunk_text,
            "parent_topics": heading["parent_topics"],
            "document": document_name,
            "chunk_summary": "",      # Placeholder for GPT summary
            "figures": []            # Will be attached later
        })

    return chunks



def match_caption_to_content(fig, content: str) -> bool:
    lines = re.findall(r"(Figura\s+\d+\s*[-–—]\s*[^\n]+)", content, flags=re.IGNORECASE)
    fig_caption = fig["caption"].lower()
    return any(fig_caption in line.lower() for line in lines)



def attach_figures_to_chunks(chunks: List[SemanticChunk], figure_metadata_dict: dict) -> List[SemanticChunk]:
    # Build index: figure number → list of matching figure dicts
    figure_metadata = list(figure_metadata_dict.values())
    fig_index = {}
    for fig in figure_metadata:
        match = re.search(r"Figura\s+(\d+)", fig["figure_id"])
        if match:
            fig_index.setdefault(match.group(1), []).append(fig)

    for chunk in chunks:
        matched_figures = []
        seen_ids = set()
        figure_nums = re.findall(r"Figura\s+(\d+)", chunk.content, flags=re.IGNORECASE)

        for num in figure_nums:
            for fig in fig_index.get(num, []):
                if fig["figure_id"] not in seen_ids and match_caption_to_content(fig, chunk.content):
                    matched_figures.append(FigureMetadata(**fig))
                    seen_ids.add(fig["figure_id"])

        chunk.figures = matched_figures

    return chunks

# %%
import re

def build_line_to_page_map(lines: List[str]) -> dict:
    line_to_page = {}
    current_page = None

    for i, line in enumerate(lines):
        match = re.search(r"Pagina\s+(\d+)\s+di\s+\d+", line, flags=re.IGNORECASE)
        if match:
            current_page = int(match.group(1))
        if current_page:
            line_to_page[i] = current_page

    return line_to_page

def strip_page_markers(lines: List[str]) -> List[str]:
    return [line for line in lines if not re.search(r"Pagina\s+\d+\s+di\s+\d+", line, re.IGNORECASE)]

def get_chunk_page_range(start_line: int, end_line: int, line_to_page: dict) -> List[int]:
    pages = [line_to_page.get(i) for i in range(start_line, end_line)]
    return sorted(set(p for p in pages if p is not None))

# %%
def normalize_section_number(sec: str) -> str:
    return sec.strip().rstrip(".")

def deduplicate_by_section_number(chunks: List[SemanticChunk]) -> List[SemanticChunk]:
    seen = {}
    removed = []
    for chunk in chunks:
        key = normalize_section_number(chunk.section_number)
        if key in seen:
            removed.append(seen[key])
        seen[key] = chunk
    return list(seen.values())

# %% [markdown]
# ## GENERATE WIFI CHUNKS

# %%
from openai import OpenAI
from instructor import from_openai
import json

client = from_openai(OpenAI(api_key="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"))


md_path = "/content/drive/MyDrive/rag_comparison/data/wifi_manual/ISTRUZIONE_OPERATIVA_CONFIGURAZIONE_WIFI_ARUBA_REV_01_cleaned.md"
document_name = "ISTRUZIONE OPERATIVA CONFIGURAZIONE WIFI ARUBA REV 01"
figure_metadata_path = '/content/drive/MyDrive/rag_comparison/data/wifi_manual/figure_metadata.json'
final_json_path = '/content/drive/MyDrive/rag_comparison/data/wifi_manual/final_wifi_chunks.json'

with open(md_path, 'r', encoding='utf-8') as f:
    markdown_text = f.read()

lines = markdown_text.splitlines()
line_to_page = build_line_to_page_map(lines)
stripped_lines = strip_page_markers(lines)
stripped_markdown = "\n".join(stripped_lines)

parsed_headings = parse_heading_structure(markdown_text)

parsed_headings = parse_heading_structure(markdown_text)
headings_with_parents = resolve_parent_topics(parsed_headings)


# Step 1: generate raw chunks from headings (already done)
raw_chunks = generate_semantic_chunks_from_headings(
    stripped_markdown,
    headings_with_parents,
    document_name,
    line_to_page=line_to_page,
    original_lines=lines  # optional: if you want page extraction aligned to real lines
)


# Step 2: convert to Pydantic objects
semantic_chunks = [SemanticChunk(**chunk) for chunk in raw_chunks]

# # Step 3: attach figures
with open(figure_metadata_path, 'r') as f:
    figure_metadata_dict = json.load(f)

semantic_chunks_with_figures = attach_figures_to_chunks(semantic_chunks, figure_metadata_dict)

# Step 4: add summaries
summarized_chunks = summarize_chunks(semantic_chunks_with_figures)



# Step 5: save final output
with open(final_json_path, 'w', encoding='utf-8') as f:
    json.dump([chunk.model_dump() for chunk in summarized_chunks], f, ensure_ascii=False, indent=2)
# Out:
# Summarizing chunks: 100%|██████████| 46/46 [06:13<00:00,  8.11s/it]

# %% [markdown]
# ## GENERATE VM CHUNKS

# %%
client = from_openai(OpenAI(api_key="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"))

md_path = "/content/drive/MyDrive/rag_comparison/data/VM_manual/ISTRUZIONE_OPERATIVA_CREAZIONE_VM_CLOUD_INSIEL_REV_00_cleaned.md"
document_name = "ISTRUZIONE OPERATIVA CREAZIONE VM CLOUD INSIEL REV 00"
figure_metadata_path = '/content/drive/MyDrive/rag_comparison/data/VM_manual/figure_metadata.json'
final_json_path = '/content/drive/MyDrive/rag_comparison/data/VM_manual/final_VM_chunks.json'

with open(md_path, 'r', encoding='utf-8') as f:
    markdown_text = f.read()

lines = markdown_text.splitlines()
line_to_page = build_line_to_page_map(lines)
stripped_lines = strip_page_markers(lines)
stripped_markdown = "\n".join(stripped_lines)

parsed_headings = parse_heading_structure(markdown_text)

parsed_headings = parse_heading_structure(markdown_text)
headings_with_parents = resolve_parent_topics(parsed_headings)


# Step 1: generate raw chunks from headings (already done)
raw_chunks = generate_semantic_chunks_from_headings(
    stripped_markdown,
    headings_with_parents,
    document_name,
    line_to_page=line_to_page,
    original_lines=lines  # optional: if you want page extraction aligned to real lines
)


# Step 2: convert to Pydantic objects
semantic_chunks = [SemanticChunk(**chunk) for chunk in raw_chunks]
deduped_chunks = deduplicate_by_section_number(semantic_chunks)

# # Step 3: attach figures
with open(figure_metadata_path, 'r') as f:
    figure_metadata_dict = json.load(f)

semantic_chunks_with_figures = attach_figures_to_chunks(deduped_chunks, figure_metadata_dict)

# Step 4: add summaries
summarized_chunks = summarize_chunks(semantic_chunks_with_figures)

# Step 5: save final output
with open(final_json_path, 'w', encoding='utf-8') as f:
    json.dump([chunk.model_dump() for chunk in summarized_chunks], f, ensure_ascii=False, indent=2)
# Out:
# Summarizing chunks: 100%|██████████| 92/92 [10:34<00:00,  6.90s/it]

# %% [markdown]
# ## Let's evaluate our new JSONs to make sure they make sense

# %%
def check_summary_quality(chunks, min_word_count=8):
    empty = [c for c in chunks if not c.chunk_summary.strip()]
    short = [c for c in chunks if len(c.chunk_summary.split()) < min_word_count]

    return {
        "empty_summaries": len(empty),
        "short_summaries": len(short),
        "examples": [(c.section_number, c.chunk_summary) for c in short[:3]]
    }

# %%
def check_figure_alignment(chunks):
    misaligned = [c for c in chunks if "Figura" in c.content and not c.figures]
    return {
        "missing_figure_links": len(misaligned),
        "examples": [(c.section_number, c.content[:200]) for c in misaligned[:3]]
    }

# %%
def estimate_token_count(text):
    return int(len(text) / 4)

def check_embedding_compatibility(chunks, max_tokens=8192):
    too_large = [c for c in chunks if estimate_token_count(c.content) > max_tokens]
    return {
        "too_large_chunks": len(too_large),
        "examples": [(c.section_number, estimate_token_count(c.content)) for c in too_large[:3]]
    }

# %%
def check_section_numbers(chunks):
    section_nums = [c.section_number for c in chunks]
    seen = set()
    duplicates = []

    for sec in section_nums:
        if sec in seen:
            duplicates.append(sec)
        seen.add(sec)

    def to_tuple(s):
        return tuple(int(x) for x in s.strip('.').split('.'))

    sorted_sections = sorted(section_nums, key=to_tuple)
    out_of_order = [s for s, t in zip(section_nums, sorted_sections) if s != t]

    return {
        "duplicates": duplicates,
        "out_of_order": out_of_order[:5]
    }

# %%
from openai import OpenAI
openai = OpenAI(api_key=OPENAI_API_KEY))

def test_retrieval_qa(chunk: SemanticChunk, question: str) -> str:
    system_prompt = "You are an expert assistant helping with technical documentation."
    context = f"Use the following document section:\n\n{chunk.content}"

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": f"{context}\n\nQuestion: {question}"}
    ]

    response = openai.chat.completions.create(
        model="gpt-4-turbo",
        messages=messages,
        temperature=0.0
    )
    return response.choices[0].message.content.strip()

# %%
import json
from typing import List

def load_chunks_from_json(path: str) -> List[SemanticChunk]:
    with open(path, "r", encoding="utf-8") as f:
        raw_data = json.load(f)

    return [SemanticChunk(**chunk) for chunk in raw_data]

# %%
def evaluate_chunks_from_valid(chunks):
    results = {}

    results.update(check_summary_quality(chunks))
    results.update(check_figure_alignment(chunks))
    results.update(check_section_numbers(chunks))
    results.update(check_embedding_compatibility(chunks))

    return results

# %%
chunks = load_chunks_from_json("/content/drive/MyDrive/rag_comparison/data/wifi_manual/final_wifi_chunks.json")
results = evaluate_chunks_from_valid(chunks)
print(results)
# Out:
# {'empty_summaries': 0, 'short_summaries': 0, 'examples': [], 'missing_figure_links': 0, 'duplicates': [], 'out_of_order': [], 'too_large_chunks': 0}

# %%
chunks = load_chunks_from_json("/content/drive/MyDrive/rag_comparison/data/VM_manual/final_VM_chunks.json")
results = evaluate_chunks_from_valid(chunks)
print(results)
# Out:
# {'empty_summaries': 0, 'short_summaries': 0, 'examples': [], 'missing_figure_links': 0, 'duplicates': [], 'out_of_order': ['5.4.1.1.6', '5.5.1.', '5.5.1.1.', '5.5.1.2.', '5.5.1.3.'], 'too_large_chunks': 0}

# %%
def print_section_order(chunks):
    def to_tuple(sec):
        return tuple(int(x) for x in sec.strip(".").split(".") if x.isdigit())

    sorted_chunks = sorted(chunks, key=lambda c: to_tuple(c.section_number))

    for chunk in sorted_chunks:
        print(chunk.section_number)

# %%
wifi_chunks = load_chunks_from_json("/content/drive/MyDrive/rag_comparison/data/wifi_manual/final_wifi_chunks.json")
print_section_order(wifi_chunks)
# Out:
# 1
# 2
# 3
# 4
# 5
# 5.1
# 5.1.1
# 5.1.2
# 5.1.3
# 5.1.3.1
# 5.1.3.1.1
# 5.1.3.1.2
# 5.1.3.1.3
# 5.1.3.1.4
# 5.1.3.2
# 5.1.3.2.1
# 5.1.3.2.2
# 5.1.3.2.3
# 5.1.3.2.4
# 5.1.3.3
# 5.1.3.3.1
# 5.1.3.4
# 5.1.3.4.1
# 5.1.3.5
# 5.1.3.5.1
# 5.1.3.6
# 5.1.3.7
# 5.1.3.8
# 5.1.3.9
# 5.1.3.10.
# 5.1.3.11.
# 5.1.3.12.
# 5.1.4
# 5.2
# 5.2.1
# 5.2.2
# 5.2.2.1
# 5.2.2.2
# 6
# 7
# 7.1
# 7.2
# 7.3
# 8
# 9
# 10

# %%
vm_chunks = load_chunks_from_json("/content/drive/MyDrive/rag_comparison/data/VM_manual/final_VM_chunks.json")
print_section_order(vm_chunks)
# Out:
# 1
# 2
# 3
# 4
# 5
# 5.1
# 5.1.1
# 5.1.2
# 5.1.3
# 5.2
# 5.2.1
# 5.2.2
# 5.2.2.1
# 5.2.2.2
# 5.3
# 5.3.1
# 5.3.1.1
# 5.3.1.2
# 5.3.1.3
# 5.3.2
# 5.3.2.1
# 5.3.2.1.1
# 5.3.2.1.2
# 5.3.2.1.3
# 5.3.2.1.3.1.
# 5.3.2.1.4
# 5.3.2.1.4.1.
# 5.3.2.1.4.2.
# 5.3.2.1.4.3.
# 5.3.2.1.4.4.
# 5.3.2.1.4.5.
# 5.4
# 5.4.1.1.1
# 5.4.1.1.2
# 5.4.1.1.2.1.
# 5.4.1.1.2.2.
# 5.4.1.1.3
# 5.4.1.1.3.1.
# 5.4.1.1.4
# 5.4.1.1.5
# 5.4.1.1.5.1.
# 5.4.1.1.5.2.
# 5.4.1.1.6
# 5.4.1.1.7
# 5.4.1.1.7.1.
# 5.4.1.1.7.2.
# 5.4.1.1.8
# 5.4.1.1.8.1.
# 5.4.1.1.9
# 5.4.1.1.9.1.
# 5.4.1.1.9.2.
# 5.4.1.1.9.3.
# 5.4.1.1.9.4.
# 5.5
# 5.5.1.
# 5.5.1.1.
# 5.5.1.2.
# 5.5.1.3.
# 5.5.1.4.
# 5.5.1.5.
# 5.5.1.6.
# 5.5.1.7.
# 5.5.1.8.
# 5.5.2.
# 5.5.2.1.
# 5.5.2.2.
# 5.5.2.3.
# 5.5.3.
# 5.5.3.1.
# 5.5.3.1.1.
# 5.5.3.1.2.
# 5.5.3.2.
# 5.5.3.3.
# 5.5.3.4.
# 5.5.3.4.1.
# 5.5.3.4.2.
# 5.5.3.5.
# 5.5.3.5.1.
# 6.
# 6.1.
# 6.2.
# 7.
# 7.1.
# 7.2.
# 8.
# 9.
# 9.1.
# 9.2.
# 9.3.
# 10.
# 11.
# 12.

# %%
def normalize_section_number(sec: str) -> str:
    return sec.strip().rstrip(".")
from collections import defaultdict

def group_chunks_by_section(chunks):
    grouped = defaultdict(list)
    for c in chunks:
        key = normalize_section_number(c.section_number)
        grouped[key].append(c)
    return {k: v for k, v in grouped.items() if len(v) > 1}  # only duplicates
def compare_duplicate_chunks(grouped):
    for section, versions in grouped.items():
        print(f"\n🔁 Duplicate Section: {section} (x{len(versions)})")
        for i, c in enumerate(versions):
            print(f"\n— Version {i+1} —")
            print(f"Title: {c.section_title}")
            print(f"Summary: {c.chunk_summary}")
            print(f"Figures: {[f.figure_id for f in c.figures]}")
            print(f"Content Preview:\n{c.content[:300]}...\n")

# %%
from collections import defaultdict

def normalize_section_number(sec: str) -> str:
    return sec.strip().rstrip(".")

def group_duplicates(chunks):
    grouped = defaultdict(list)
    for c in chunks:
        norm = normalize_section_number(c.section_number)
        grouped[norm].append(c)
    return {k: v for k, v in grouped.items() if len(v) > 1}

import difflib

def analyze_duplicates(grouped):
    comparison_report = []

    for section, versions in grouped.items():
        if len(versions) != 2:
            continue

        v1, v2 = versions

        v1_words = len(v1.content.split())
        v2_words = len(v2.content.split())

        v1_figs = len(v1.figures)
        v2_figs = len(v2.figures)

        # summary_ratio = difflib.SequenceMatcher(None, v1.chunk_summary, v2.chunk_summary).ratio()
        content_ratio = difflib.SequenceMatcher(None, v1.content, v2.content).ratio()

        comparison_report.append({
            "section": section,
            "v1_words": v1_words,
            "v2_words": v2_words,
            "v1_figures": v1_figs,
            "v2_figures": v2_figs,
            # "summary_similarity": round(summary_ratio, 2),
            "content_similarity": round(content_ratio, 2),
            "v1_preview": v1.content[:150].strip(),
            "v2_preview": v2.content[:150].strip()
        })

    return comparison_report

# %%
duplicates = group_chunks_by_section(wifi_chunks)

# Compare side-by-side
compare_duplicate_chunks(duplicates)

# %%
duplicates = group_chunks_by_section(vm_chunks)

# Compare side-by-side
compare_duplicate_chunks(duplicates)

# %%
import pandas as pd
groups = group_duplicates(vm_chunks)
comparison_report = analyze_duplicates(groups)
df = pd.DataFrame(comparison_report)
df.sort_values("v2_words", ascending=False)
# Out:
#       section  v1_words  v2_words  v1_figures  v2_figures  content_similarity  \
# 38         12        10       775           0          53                0.01
# 26        6.1         5       160           0           0                0.05
# 0   5.4.1.1.6        52        96           0           2                0.03
# 30        7.2         4        74           0           0                0.08
# 7     5.5.1.6         6        72           0           0                0.15
# 27        6.2        10        58           0           0                0.27
# 31          8         5        53           0           0                0.18
# 6     5.5.1.5         4        52           0           0                0.17
# 15    5.5.3.1         5        32           0           0                0.28
# 8     5.5.1.7         5        30           0           0                0.30
# 9     5.5.1.8         6        27           0           0                0.30
# 2     5.5.1.1         6        27           0           0                0.35
# 5     5.5.1.4         4        27           0           0                0.28
# 4     5.5.1.3         4        27           0           0                0.30
# 11    5.5.2.1         5        26           0           0                0.28
# 10      5.5.2         4        25           0           0                0.26
# 29        7.1         5        23           0           0                0.33
# 3     5.5.1.2         5        20           0           0                0.49
# 35        9.3         4        13           0           0                0.14
# 24  5.5.3.5.1         7        13           0           0                0.73
# 28          7         7        12           0           0                0.69
# 25          6        11        11           0           0                1.00
# 34        9.2         4         8           0           0                0.26
# 33        9.1         4         8           0           0                0.28
# 17  5.5.3.1.2         3         8           0           0                0.50
# 37         11         5         7           0           0                0.84
# 21  5.5.3.4.1         6         6           0           0                1.00
# 36         10         4         6           0           0                0.45
# 32          9         6         6           0           0                1.00
# 19    5.5.3.3         6         6           0           0                1.00
# 16  5.5.3.1.1         5         5           0           0                0.53
# 18    5.5.3.2         5         5           0           0                1.00
# 13    5.5.2.3         5         5           0           0                1.00
# 22  5.5.3.4.2         5         5           0           0                0.78
# 20    5.5.3.4         5         5           0           0                1.00
# 1       5.5.1         4         4           0           0                0.98
# 14      5.5.3         4         4           0           0                1.00
# 12    5.5.2.2         4         4           0           0                1.00
# 23    5.5.3.5         4         4           0           0                1.00
#
#                                            v1_preview  \
# 38  ## 12. INDICE DELLE FIGURE\n\n\n\n\n*Pagina 5 ...
# 26                          ### 6.1. SEGMENTI DI RETE
# 0   ##### 5.4.1.1.6 NAT47\n##### 5.4.1.1.7 DNS.......
# 30                               ### 7.2. NOMI GRUPPI
# 7            ### 5.5.1.6. ESPANSIONE DISCO DI SISTEMA
# 27  ### 6.2. RANGE DI IP DEDICATI PER TIPOLOGIA DI...
# 31                ## 8. GESTIONE DELLA DOCUMENTAZIONE
# 6                      ### 5.5.1.5. DISCHI AGGIUNTIVI
# 15                    ### 5.5.3.1. MODIFICA NOME HOST
# 8                ### 5.5.1.7. CAMBIO DENOMINAZIONE VM
# 9                  ### 5.5.1.8. PRIMO ACCESSO ALLA VM
# 2                ### 5.5.1.1. ACCESSO A CLOUD MANAGER
# 5                      ### 5.5.1.4. VERIFICA CAPIENZA
# 4                      ### 5.5.1.3. SELEZIONE T-SHIRT
# 11                         ### 5.5.2.1. ACCESSO A NSX
# 10                          ## 5.5.2. REGOLE FIREWALL
# 29                    ### 7.1. NOMI MACCHINE VIRTUALI
# 3            ### 5.5.1.2. SELEZIONE SISTEMA OPERATIVO
# 35                               ### 9.3. VMWARE ARIA
# 24  #### 5.5.3.5.1. VERIFICA FUNZIONAMENTO SU CONS...
# 28              ## 7. APPENDICE 2 – NAMING CONVENTION
# 25  ## 6. APPENDICE 1 – CRITERI DI ASSEGNAZIONE DE...
# 34                                ### 9.2. VMWARE NSX
# 33                            ### 9.1. VMWARE VSPHERE
# 17                              #### 5.5.3.1.2. Linux
# 37                      ## 11. ALLEGATI (SE PRESENTI)
# 21           #### 5.5.3.4.1. VERIFICA SU CONSOLE WSUS
# 36                         ## 10. DOCUMENTI COLLEGATI
# 32      ## 9. RIFERIMENTI (NORMATIVI E BIBLIOGRAFICI)
# 19           ### 5.5.3.3. ESPANSIONE DISCO DI SISTEMA
# 16           #### 5.5.3.1.1. Microsoft Windows Server
# 18                    ### 5.5.3.2. AGGIUNTA A DOMINIO
# 13                      ### 5.5.2.3. PROBLEMI DI RETE
# 22           #### 5.5.3.4.2. AGGIORNAMENTO e patching
# 20       ### 5.5.3.4. AGGIORNAMENTO SISTEMA OPERATIVO
# 1                              ## 5.5.1. CREAZIONE VM
# 14                        ## 5.5.3. CONFIGURAZIONE VM
# 12                 ### 5.5.2.2. CONFIGURAZIONE REGOLE
# 23               ### 5.5.3.5. INSTALLAZIONE ANTIVIRUS
#
#                                            v2_preview
# 38  # 12. INDICE DELLE FIGURE\n\nFIGURA 1 - VMWARE...
# 26  ### 6.1. SEGMENTI DI RETE\n\nNello IaaS INSIEL...
# 0   ##### 5.4.1.1.6 NAT\n\n\n\n\n\n\nNessuna regol...
# 30  ## 7.2. NOMI GRUPPI\n\nPer i nomi dei gruppi v...
# 7   ### 5.5.1.6. ESPANSIONE DISCO DI SISTEMA\nIn f...
# 27  ### 6.2. RANGE DI IP DEDICATI PER TIPOLOGIA DI...
# 31  ## 8. GESTIONE DELLA DOCUMENTAZIONE\n\nNel pre...
# 6   ### 5.5.1.5. DISCHI AGGIUNTIVI\nÈ possibile ch...
# 15  ### 5.5.3.1. MODIFICA NOME HOST\nIl nome host ...
# 8   ### 5.5.1.7. CAMBIO DENOMINAZIONE VM\nDopo la ...
# 9   ### 5.5.1.8. PRIMO ACCESSO ALLA VM\nInfine, è ...
# 2   #### 5.5.1.1. ACCESSO A CLOUD MANAGER\nPer l'a...
# 5   ### 5.5.1.4. VERIFICA CAPIENZA\nÈ possibile ch...
# 4   #### 5.5.1.3. SELEZIONE T-SHIRT\nLa selezione ...
# 11  ### 5.5.2.1. ACCESSO A NSX\nPer l'accesso al c...
# 10  ## 5.5.2. REGOLE FIREWALL\nDopo la creazione d...
# 29  ## 7.1. NOMI MACCHINE VIRTUALI\n\nAnalogamente...
# 3   #### 5.5.1.2. SELEZIONE SISTEMA OPERATIVO\nLa ...
# 35  ### 9.3. VMWARE ARIA\n- HTTPS://DOCS.VMWARE.CO...
# 24  #### 5.5.3.5.1. VERIFICA FUNZIONAMENTO SU CONS...
# 28  ## 7. APPENDICE 2 – NAMING CONVENTION\n\n\n\n*...
# 25  ## 6. APPENDICE 1 – CRITERI DI ASSEGNAZIONE DE...
# 34  ### 9.2. VMWARE NSX\n- HTTPS://WWW.VMWARE.COM/...
# 33  ### 9.1. VMWARE VSPHERE\n- HTTPS://WWW.VMWARE....
# 17  #### 5.5.3.1.2. LINUX\n\n\n\n*Pagina 60 di 66 ...
# 37         ## 11. ALLEGATI (SE PRESENTI)\n\n• Nessuno
# 21           #### 5.5.3.4.1. VERIFICA SU CONSOLE WSUS
# 36  ## 10. DOCUMENTI COLLEGATI\n\n• HTTPS://WIKI.A...
# 32      ## 9. RIFERIMENTI (NORMATIVI E BIBLIOGRAFICI)
# 19           ### 5.5.3.3. ESPANSIONE DISCO DI SISTEMA
# 16           #### 5.5.3.1.1. MICROSOFT WINDOWS SERVER
# 18                    ### 5.5.3.2. AGGIUNTA A DOMINIO
# 13                      ### 5.5.2.3. PROBLEMI DI RETE
# 22           #### 5.5.3.4.2. AGGIORNAMENTO E PATCHING
# 20       ### 5.5.3.4. AGGIORNAMENTO SISTEMA OPERATIVO
# 1                             ### 5.5.1. CREAZIONE VM
# 14                        ## 5.5.3. CONFIGURAZIONE VM
# 12                 ### 5.5.2.2. CONFIGURAZIONE REGOLE
# 23               ### 5.5.3.5. INSTALLAZIONE ANTIVIRUS

# %%
# for c in summarized_chunks:
#     c.section_number = normalize_section_number(c.section_number)

deduped_chunks = deduplicate_by_section_number(vm_chunks)

with open("/content/drive/MyDrive/rag_comparison/data/VM_manual/final_VM_chunks.json", "w", encoding="utf-8") as f:
    json.dump([c.model_dump() for c in deduped_chunks], f, ensure_ascii=False, indent=2)
# Out:
# ❌ Removed 39 duplicates.

# %%
def extract_used_figures(chunks: List[SemanticChunk]) -> set:
    used = set()
    for chunk in chunks:
        for fig in chunk.figures:
            used.add(fig["figure_id"] if isinstance(fig, dict) else fig.figure_id)
    return used
def compare_figures(fig_metadata, chunks):
    defined = {fig["figure_id"] for fig in fig_metadata}
    used = extract_used_figures(chunks)

    missing_from_chunks = defined - used
    unknown_figures = used - defined

    return {
        "defined_total": len(defined),
        "used_total": len(used),
        "unused_figures": sorted(missing_from_chunks),
        "invalid_figures": sorted(unknown_figures)
    }

# %%
def load_figure_metadata_from_dict(path):
    with open(path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # Validate structure
    if not isinstance(data, dict):
        raise ValueError("Expected figure metadata to be a dictionary")

    # Flatten into a list of metadata dictionaries
    return list(data.values())

# %%
# Load chunk JSON and figure metadata
vm_chunks = load_chunks_from_json("/data/VM_manual/final_VM_chunks.json")
vm_figures = load_figure_metadata_from_dict("/data/VM_manual/figure_metadata.json")

# Run figure comparison
report = compare_figures(vm_figures, vm_chunks)
print(json.dumps(report, indent=2))
# Out:
# {
#   "defined_total": 90,
#   "used_total": 90,
#   "unused_figures": [],
#   "invalid_figures": []
# }

# %%
from typing import List

def find_chunk_references(fig_number: str, chunks: List[SemanticChunk]):
    results = []
    pattern = re.compile(rf"(Figura\s+{fig_number}\s*-\s*[^\n]+)", re.IGNORECASE)

    for chunk in chunks:
        matches = pattern.findall(chunk.content)
        if matches:
            results.append({
                "section": chunk.section_number,
                "title": chunk.section_title,
                "matched_lines": matches,
                "attached_figures": [fig.figure_id if hasattr(fig, "figure_id") else fig["figure_id"] for fig in chunk.figures]
            })
    return results

# %%
for fig_num in ["21", "30", "44"]:
    print(f"\n🔎 Figura {fig_num} references:")
    refs = find_chunk_references(fig_num, vm_chunks)
    for r in refs:
        print(f"\n📘 {r['section']} – {r['title']}")
        for line in r["matched_lines"]:
            print(f"   🔹 {line}")
        print(f"   ✅ Attached figures: {r['attached_figures']}")
# Out:
# 🔎 Figura 21 references:
#
# 🔎 Figura 30 references:
#
# 🔎 Figura 44 references:

# %% [markdown]
# ahhhh we have 3 figure 69 but we match on figure num and then just attribute the first figure match!!!

# %%
wifi_chunks = load_chunks_from_json("/data/wifi_manual/final_wifi_chunks.json")
wifi_figures = load_figure_metadata_from_dict("/data/wifi_manual/figure_metadata.json")

# Run figure comparison
report = compare_figures(wifi_figures, wifi_chunks)
print(json.dumps(report, indent=2))
# Out:
# {
#   "defined_total": 49,
#   "used_total": 49,
#   "unused_figures": [],
#   "invalid_figures": []
# }

# %%
test_chunk1 = {
    "section_number": "5.4.1.1.6",
    "section_title": "NAT",
    "content": "##### 5.4.1.1.6 NAT\n\n\n\n\n\n\nNessuna regola NAT definita. È possibile iniziare facendo clic su \"Aggiungi regola NAT\"\n\nFigura 68 - VMWare NSX – Rete – NAT\n\nSono presenti nella griglia i seguenti campi:\n\n- Nome.\n\n- Azione.\n\n- Associa.\n\n- IP di origine.\n\n- IP di destinazione/Porta.\n\n- IP convertito/Porta.\n\n- Applica a.\n\n- Abilitata.\n\n- Stato.\n\n\n\n*Pagina 48 di 66 (22/10/2024)*\n\n\nFigura 69 - VMWare NSX – Rete – NAT – Configurazione NAT\n\nQuesta funzionalità è utile per configurare NAT nel contesto di un gateway di Livello 1 predefinito.\nAl momento non sono presenti NAT configurati.",
    "parent_topics": [
      "MODALITÀ ESECUTIVE",
      "CLOUD FIREWALL",
      "PROFILI"
    ],
    "document": "ISTRUZIONE OPERATIVA CREAZIONE VM CLOUD INSIEL REV 00",
    "chunk_summary": "This section of the technical manual, titled 'MODALITÀ ESECUTIVE > CLOUD FIREWALL > PROFILI > NAT', focuses on the configuration and management of Network Address Translation (NAT) rules within a VMWare NSX environment. It begins by indicating that no NAT rules are currently defined and provides a prompt to add new NAT rules. Key fields listed for rule configuration include Name, Action, Bind, Source IP, Destination IP/Port, Translated IP/Port, Apply to, Enabled, and Status. Two figures are included: one showing the NAT network setup and another detailing the NAT configuration steps, emphasizing the utility of NAT in the context of a predefined Level 1 gateway.",
    "figures": []
}

test_chunk2 = {
    "section_number": "5.4.1.1.7.1.",
    "section_title": "SERVIZI DNS",
    "content": """#### 5.4.1.1.7.1.SERVIZI DNS

Figura 69 - VMWare NSX – DNS – Servizi DNS

Sono presenti nella griglia i seguenti campi:

- Nome

- Gateway
- IP servizio DNS
- Zona DNS predefinita
- Zona FQDN
- Stato

Figura 69 - VMWare NSX – DNS – Servizi DNS – Configurazione DNS

Non vi sono servizi DNS configurati a livello di NSX.

NOTA BENE:
- I servizi DNS vengono forniti nel contesto dell'Active Directory.
- Tipicamente i servizi DNS vengono configurati manualmente sia per le VM collegate al dominio che per le VM non collegate al dominio.""",
    "figures": []
}

# %%
import re

def match_caption_to_content(fig, content: str) -> bool:
    lines = re.findall(r"(Figura\s+\d+\s*-\s*[^\n]+)", content, flags=re.IGNORECASE)
    fig_caption = fig["caption"].lower()
    return any(fig_caption in line.lower() for line in lines)

def simulate_attach_figures(chunk, figure_metadata_list):
    fig_index = {}
    for fig in figure_metadata_list:
        match = re.search(r"Figura\s+(\d+)", fig["figure_id"])
        if match:
            fig_index.setdefault(match.group(1), []).append(fig)

    matched_figures = []
    seen_ids = set()

    figure_nums = re.findall(r"Figura\s+(\d+)", chunk["content"], flags=re.IGNORECASE)

    for num in figure_nums:
        for fig in fig_index.get(num, []):
            if fig["figure_id"] not in seen_ids and match_caption_to_content(fig, chunk["content"]):
                matched_figures.append(fig)
                seen_ids.add(fig["figure_id"])

    return matched_figures

# %%
matched = simulate_attach_figures(test_chunk1, vm_figures)

for fig in matched:
    print(f"✅ Matched: {fig['figure_id']}")
# Out:
# ✅ Matched: Figura 68_vmware_nsx__rete__nat
# ✅ Matched: Figura 69_vmware_nsx__rete__nat__configurazione_nat

# %%
matched = simulate_attach_figures(test_chunk2, vm_figures)

for fig in matched:
    print(f"✅ Matched: {fig['figure_id']}")
# Out:
# ✅ Matched: Figura 69_vmware_nsx__dns__servizi_dns
# ✅ Matched: Figura 69_vmware_nsx__dns__servizi_dns__configurazione_dns

# %% [markdown]
# Clean JSON even more to seperate some metadata

# %%
import json
import re
from pathlib import Path

def clean_whitespace(text: str) -> str:
    """Normalize excessive whitespace without changing content."""
    # Replace 3+ newlines with double newlines
    text = re.sub(r'\n{3,}', '\n\n', text)
    # Remove trailing whitespace from lines
    text = re.sub(r'[ \t]+$', '', text, flags=re.MULTILINE)
    return text.strip()

def determine_section_type(section_title: str) -> str:
    """Determine section type based on the title."""
    title_lower = section_title.lower()

    if any(word in title_lower for word in ["configurazione", "config", "setup"]):
        return "configuration"
    elif any(word in title_lower for word in ["verifica", "test", "check"]):
        return "verification"
    elif any(word in title_lower for word in ["dettaglio", "detail"]):
        return "detail"
    elif any(word in title_lower for word in ["introduzione", "scopo", "ambito"]):
        return "introduction"
    elif any(word in title_lower for word in ["riferimenti", "allegati", "indice"]):
        return "reference"
    else:
        return "general"

def transform_chunk(chunk):
    """Transform a chunk to standardized format while preserving content."""
    # Extract basic fields
    section_id = chunk.get("section_number", "")
    section_title = chunk.get("section_title", "")
    page_numbers = chunk.get("page_numbers", [])

    # Format page range
    if not page_numbers:
        page_range = ""
    elif len(page_numbers) == 1:
        page_range = str(page_numbers[0])
    else:
        page_range = f"{min(page_numbers)}-{max(page_numbers)}"

    # Create parent path from topics
    parent_path = " > ".join(chunk.get("parent_topics", []))

    # Clean content by only normalizing whitespace
    content = clean_whitespace(chunk.get("content", ""))
    content_summary = chunk.get("chunk_summary", "").strip()

    # Process figures
    figures = []
    for fig in chunk.get("figures", []):
        figures.append({
            "figure_id": fig.get("figure_id", "").replace(" ", "_"),
            "filename": fig.get("filename", ""),
            "caption": fig.get("caption", "").capitalize(),
            "page": fig.get("page", "")
        })

    # Create standardized chunk
    return {
        "section_id": section_id,
        "section_title": section_title,
        "page_range": page_range,
        "parent_path": parent_path,
        "document": chunk.get("document", ""),
        "content": content,
        "content_summary": content_summary,
        "figures": figures,
        "metadata": {
            "original_section_number": section_id,
            "original_page_numbers": page_numbers,
            "language": "Italian",
            "section_type": determine_section_type(section_title)
        }
    }

def process_manual(input_file, output_file):
    """Process a manual JSON file and save the standardized output."""
    with open(input_file, "r", encoding="utf-8") as f:
        data = json.load(f)

    transformed = [transform_chunk(chunk) for chunk in data]

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(transformed, f, indent=2, ensure_ascii=False)

    print(f"✓ {len(transformed)} chunks written to {output_file}")

# %%
wifi_input = "/data/wifi_manual/final_wifi_chunks.json"
wifi_output = "/data/wifi_manual/cleaned_wifi_chunks.json"
process_manual(wifi_input, wifi_output)
# Out:
# ✓ 46 chunks written to /content/drive/MyDrive/rag_comparison/data/wifi_manual/cleaned_wifi_chunks.json

# %%
vm_input = "/data/VM_manual/final_VM_chunks.json"
vm_output = "/data/VM_manual/cleaned_VM_chunks.json"
process_manual(vm_input, vm_output)
# Out:
# ✓ 92 chunks written to /content/drive/MyDrive/rag_comparison/data/VM_manual/cleaned_VM_chunks.json
